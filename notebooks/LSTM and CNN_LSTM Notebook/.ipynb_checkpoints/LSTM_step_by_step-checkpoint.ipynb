# %% [markdown]
# # LSTM Indoor Air Forecasting - Step by Step
#
# This notebook expands the logic from:
#
# - `dataPipeline_LSTM.py`
# - `src/LSTM/dataLoad.py`
# - `src/LSTM/LSTM.py`
#
# The original pipeline runs the complete LSTM workflow through one function call. Here, the same important logic is separated into notebook-style cells so you can execute and understand each modeling step.

# %% [markdown]
# ## 1. Import Libraries
#
# These imports combine the data loading, EDA, PCA, preprocessing, PyTorch model, dataloaders, scaling, training, and evaluation logic from the original files.

# %%
import os
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# ## 2. Reproducibility and Paths
#
# The wrapper script uses `data/indoorAir.csv`, while the LSTM data loader default mentions `data/indoorAir2.csv`. This cell checks both possible filenames and uses whichever exists.

# %%
# SEED = 42
# random.seed(SEED)
# np.random.seed(SEED)
# torch.manual_seed(SEED)

PROJECT_DIR = r"C:\Users\Kenil Dhorajiya\Downloads\University\Semester 5\Project\TSA"
DATA_CANDIDATES = [
    os.path.join(PROJECT_DIR, "data", "indoorAir.csv"),
    os.path.join(PROJECT_DIR, "data", "indoorAir2.csv"),
]

CSV_PATH = next((path for path in DATA_CANDIDATES if os.path.exists(path)), None)
if CSV_PATH is None:
    raise FileNotFoundError(f"Could not find any data file from: {DATA_CANDIDATES}")

CSV_PATH
# Out:
# 'C:\\Users\\Kenil Dhorajiya\\Downloads\\University\\Semester 5\\Project\\TSA\\data\\indoorAir2.csv'

# %% [markdown]
# ## 3. Model Configuration
#
# These constants come from `LSTM.py`. The target is `scd41_co2`, and historical CO2 is also included as an input feature for forecasting future CO2.

# %%
BASE_FEATURES = [
    "ens160_aqi",
    "ens160_tvoc",
    "bme688_gas_resistance",
    "bme688_pressure",
    "scd41_temperature",
    "scd41_humidity",
    "scd41_co2",
    "hour_sin",
    "hour_cos",
    "dayofweek_sin",
    "dayofweek_cos",
    "is_weekend",
]

PCA_FEATURES = [
    "ens160_aqi",
    "ens160_tvoc",
    "bme688_gas_resistance",
    "bme688_pressure",
    "scd41_temperature",
    "scd41_humidity",
]

TARGET = "scd41_co2"
STATION_COLUMN = "station_id"

INPUT_SEQ_LENGTH = 24
OUTPUT_SEQ_LENGTH = 6
BATCH_SIZE = 32
EPOCHS = 10

# %% [markdown]
# ## 4. Load and Prepare Raw Dataset
#
# This is the notebook version of `load_prepare_data`: read CSV, print dataset information, convert Unix-second timestamps, sort chronologically, and set timestamp as the index.

# %%
df = pd.read_csv(CSV_PATH)

print("========== RAW DATASET ==========")
print("Raw dataset shape:", df.shape)
print("\nColumns in dataset:")
print(df.columns.tolist())

df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")
df = df.sort_values(by="timestamp")
df = df.set_index("timestamp")

print("\n========== TIMESTAMP PROCESSING ==========")
print("\nDataset shape after timestamp processing:", df.shape)
print("\nDate range:")
print("Start:", df.index.min())
print("End:", df.index.max())

df.head()
# Out:
# ========== RAW DATASET ==========
# Raw dataset shape: (1924653, 21)
#
# Columns in dataset:
# ['id', 'station_id', 'station_name', 'timestamp', 'scd41_co2', 'scd41_temperature', 'scd41_humidity', 'ens160_eco2', 'ens160_tvoc', 'ens160_aqi', 'svm41_temperature', 'svm41_humidity', 'svm41_nox_index', 'svm41_voc_index', 'bme688_temperature', 'bme688_humidity', 'bme688_pressure', 'bme688_gas_resistance', 'sfa30_temperature', 'sfa30_humidity', 'sfa30_hco']
#
# ========== TIMESTAMP PROCESSING ==========
#
# Dataset shape after timestamp processing: (1924653, 20)
#
# Date range:
# Start: 2024-11-13 16:57:56
# End: 2026-04-22 13:10:59
#                      id  station_id      station_name  scd41_co2  \
# timestamp
# 2024-11-13 16:57:56   1           1  station_room_233      488.0
# 2024-11-13 16:58:57   2           1  station_room_233      485.0
# 2024-11-13 16:59:59   3           1  station_room_233      477.0
# 2024-11-13 17:01:03   4           1  station_room_233      474.0
# 2024-11-13 17:02:05   5           1  station_room_233      473.0
#
#                      scd41_temperature  scd41_humidity  ens160_eco2  \
# timestamp
# 2024-11-13 16:57:56          22.951857       36.897277          418
# 2024-11-13 16:58:57          22.335011       38.185119          414
# 2024-11-13 16:59:59          22.353704       38.400268          443
# 2024-11-13 17:01:03          22.417792       38.269042          406
# 2024-11-13 17:02:05          22.556649       37.971496          416
#
#                      ens160_tvoc  ens160_aqi  svm41_temperature  \
# timestamp
# 2024-11-13 16:57:56           32           1          23.684999
# 2024-11-13 16:58:57           30           1          23.590000
# 2024-11-13 16:59:59           43           1          23.655000
# 2024-11-13 17:01:03           26           1          23.709999
# 2024-11-13 17:02:05           31           1          23.659999
#
#                      svm41_humidity  svm41_nox_index  svm41_voc_index  \
# timestamp
# 2024-11-13 16:57:56       34.060001             29.0              1.0
# 2024-11-13 16:58:57       34.209999             79.0              1.0
# 2024-11-13 16:59:59       34.180000             99.0              1.0
# 2024-11-13 17:01:03       34.130001             93.0              1.0
# 2024-11-13 17:02:05       34.240001             98.0              1.0
#
#                      bme688_temperature  bme688_humidity  bme688_pressure  \
# timestamp
# 2024-11-13 16:57:56                 NaN              NaN              NaN
# 2024-11-13 16:58:57                 NaN              NaN              NaN
# 2024-11-13 16:59:59                 NaN              NaN              NaN
# 2024-11-13 17:01:03                 NaN              NaN              NaN
# 2024-11-13 17:02:05                 NaN              NaN              NaN
#
#                      bme688_gas_resistance  sfa30_temperature  sfa30_humidity  \
# timestamp
# 2024-11-13 16:57:56                    NaN                NaN             NaN
# 2024-11-13 16:58:57                    NaN                NaN             NaN
# 2024-11-13 16:59:59                    NaN                NaN             NaN
# 2024-11-13 17:01:03                    NaN                NaN             NaN
# 2024-11-13 17:02:05                    NaN                NaN             NaN
#
#                      sfa30_hco
# timestamp
# 2024-11-13 16:57:56        NaN
# 2024-11-13 16:58:57        NaN
# 2024-11-13 16:59:59        NaN
# 2024-11-13 17:01:03        NaN
# 2024-11-13 17:02:05        NaN

# %% [markdown]
# ## 5. Initial Data Inspection
#
# This notebook-only check helps confirm station IDs, missing values, and basic numeric ranges before preprocessing.

# %%
print("Stations available:", sorted(df[STATION_COLUMN].dropna().unique().tolist()))
print("Total missing values:", df.isna().sum().sum())

df.describe(include="all").T.head(20)
# Out:
# Stations available: [1, 2, 3, 4, 5, 6]
# Total missing values: 8501922
#                            count unique               top    freq  \
# id                     1924653.0    NaN               NaN     NaN
# station_id             1924653.0    NaN               NaN     NaN
# station_name             1924653      6  station_room_233  586547
# scd41_co2              1924653.0    NaN               NaN     NaN
# scd41_temperature      1924653.0    NaN               NaN     NaN
# scd41_humidity         1924653.0    NaN               NaN     NaN
# ens160_eco2            1924653.0    NaN               NaN     NaN
# ens160_tvoc            1924653.0    NaN               NaN     NaN
# ens160_aqi             1924653.0    NaN               NaN     NaN
# svm41_temperature      1155267.0    NaN               NaN     NaN
# svm41_humidity         1155267.0    NaN               NaN     NaN
# svm41_nox_index        1155267.0    NaN               NaN     NaN
# svm41_voc_index        1155267.0    NaN               NaN     NaN
# bme688_temperature     1881393.0    NaN               NaN     NaN
# bme688_humidity        1881393.0    NaN               NaN     NaN
# bme688_pressure        1881393.0    NaN               NaN     NaN
# bme688_gas_resistance  1881393.0    NaN               NaN     NaN
# sfa30_temperature       174207.0    NaN               NaN     NaN
# sfa30_humidity          174207.0    NaN               NaN     NaN
# sfa30_hco               174207.0    NaN               NaN     NaN
#
#                                   mean            std         min         25%  \
# id                       962329.700152  555600.075605         1.0    481167.0
# station_id                    2.847304       1.447816         1.0         1.0
# station_name                       NaN            NaN         NaN         NaN
# scd41_co2                   533.239516     233.990075       365.0       429.0
# scd41_temperature             24.66657       1.750211   15.936903   23.443198
# scd41_humidity               35.090718       8.362188   14.282226   28.643798
# ens160_eco2                 735.495093    3417.101072         0.0       451.0
# ens160_tvoc                 111.988025     354.955305         0.0        47.0
# ens160_aqi                    1.624931         0.7108         0.0         1.0
# svm41_temperature            24.488481       1.842034      -0.005       23.29
# svm41_humidity               35.171222      11.049058 -327.459991        28.6
# svm41_nox_index             111.133658      61.803516        -0.1        75.0
# svm41_voc_index               1.164915       0.517066        -0.1         1.0
# bme688_temperature           26.845749       1.616929       20.03       25.81
# bme688_humidity              26.965543       7.401234       9.198      21.177
# bme688_pressure             100.133822       0.795506       96.22      99.734
# bme688_gas_resistance  12939033.965337   26606.016879  12887828.0  12917167.0
# sfa30_temperature            26.502268       1.321611       24.28       25.67
# sfa30_humidity               28.220087       7.905439   11.319999       21.93
# sfa30_hco                     3.777878       6.298218         0.2         0.6
#
#                               50%         75%         max
# id                       962330.0   1443493.0   1924656.0
# station_id                    3.0         4.0         6.0
# station_name                  NaN         NaN         NaN
# scd41_co2                   457.0       523.0     32774.0
# scd41_temperature        24.51934   25.664911       130.0
# scd41_humidity          33.636474   40.940856   99.998474
# ens160_eco2                 494.0       578.0     65522.0
# ens160_tvoc                  69.0       117.0     65488.0
# ens160_aqi                    2.0         2.0       154.0
# svm41_temperature           24.29   25.344999   41.439998
# svm41_humidity          33.349998   41.409999  325.339996
# svm41_nox_index             101.0       132.0       500.0
# svm41_voc_index               1.0         1.0        25.5
# bme688_temperature          26.73       27.65        44.2
# bme688_humidity            25.772      32.401      68.171
# bme688_pressure            100.22     100.689     102.508
# bme688_gas_resistance  12946860.0  12946860.0  12976914.0
# sfa30_temperature          26.065      26.975   32.459999
# sfa30_humidity          26.719999   34.049999   53.310001
# sfa30_hco                     1.0         3.0   35.400001

# %% [markdown]
# ## 6. Optional EDA: CO2 Time Series
#
# This matches `plot_time_series` from `src/LSTM/dataLoad.py`.

# %%
plt.figure(figsize=(10, 4))
plt.plot(df[TARGET])
plt.title("CO2 Time Series")
plt.xlabel("Timestamp")
plt.ylabel("CO2")
plt.show()

# %% [markdown]
# ## 7. Optional EDA: Correlation Heatmap
#
# This matches `plot_heatmap`.

# %%
corr = df.select_dtypes(include=["float64", "int64"]).corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## 8. Optional EDA: PCA Analysis
#
# This follows `plot_pca_analysis`. It uses only selected clean input features, fills missing values with time interpolation and forward/backward fill, standardizes the data, and plots cumulative explained variance.

# %%
numerical_df = df[PCA_FEATURES].copy()
numerical_df = (
    numerical_df
    .interpolate(method="time")
    .ffill()
    .bfill()
    .dropna()
)

standard_scaler = StandardScaler()
scaled_data = standard_scaler.fit_transform(numerical_df)

pca = PCA()
pca.fit(scaled_data)

explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()

print("========== PCA ANALYSIS ==========")
print("Explained Variance Ratio:")
print(explained_variance)
print("\nCumulative Variance:")
print(cumulative_variance)

plt.figure(figsize=(8, 4))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker="o")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Cumulative Explained Variance")
plt.grid(True)
plt.show()
# Out:
# ========== PCA ANALYSIS ==========
# Explained Variance Ratio:
# [0.25181935 0.19757189 0.18862874 0.15373756 0.10822613 0.10001632]
#
# Cumulative Variance:
# [0.25181935 0.44939124 0.63801998 0.79175755 0.89998368 1.        ]

# %% [markdown]
# ## 9. Add Time Features
#
# This is the exact cyclical time feature logic from `add_time_features`. Hour and day of week are represented with sine/cosine pairs, and weekend is added as a binary feature.

# %%
def add_time_features(input_df):
    output_df = input_df.copy()

    hour = output_df.index.hour
    dayofweek = output_df.index.dayofweek

    output_df["hour_sin"] = np.sin(2 * np.pi * hour / 24)
    output_df["hour_cos"] = np.cos(2 * np.pi * hour / 24)
    output_df["dayofweek_sin"] = np.sin(2 * np.pi * dayofweek / 7)
    output_df["dayofweek_cos"] = np.cos(2 * np.pi * dayofweek / 7)
    output_df["is_weekend"] = (dayofweek >= 5).astype(int)

    return output_df

df_with_time = add_time_features(df)
df_with_time[BASE_FEATURES + [STATION_COLUMN]].head()
# Out:
#                      ens160_aqi  ens160_tvoc  bme688_gas_resistance  \
# timestamp
# 2024-11-13 16:57:56           1           32                    NaN
# 2024-11-13 16:58:57           1           30                    NaN
# 2024-11-13 16:59:59           1           43                    NaN
# 2024-11-13 17:01:03           1           26                    NaN
# 2024-11-13 17:02:05           1           31                    NaN
#
#                      bme688_pressure  scd41_temperature  scd41_humidity  \
# timestamp
# 2024-11-13 16:57:56              NaN          22.951857       36.897277
# 2024-11-13 16:58:57              NaN          22.335011       38.185119
# 2024-11-13 16:59:59              NaN          22.353704       38.400268
# 2024-11-13 17:01:03              NaN          22.417792       38.269042
# 2024-11-13 17:02:05              NaN          22.556649       37.971496
#
#                      scd41_co2  hour_sin  hour_cos  dayofweek_sin  \
# timestamp
# 2024-11-13 16:57:56      488.0 -0.866025 -0.500000       0.974928
# 2024-11-13 16:58:57      485.0 -0.866025 -0.500000       0.974928
# 2024-11-13 16:59:59      477.0 -0.866025 -0.500000       0.974928
# 2024-11-13 17:01:03      474.0 -0.965926 -0.258819       0.974928
# 2024-11-13 17:02:05      473.0 -0.965926 -0.258819       0.974928
#
#                      dayofweek_cos  is_weekend  station_id
# timestamp
# 2024-11-13 16:57:56      -0.222521           0           1
# 2024-11-13 16:58:57      -0.222521           0           1
# 2024-11-13 16:59:59      -0.222521           0           1
# 2024-11-13 17:01:03      -0.222521           0           1
# 2024-11-13 17:02:05      -0.222521           0           1

# %% [markdown]
# ## 10. Preprocess: Feature Selection and 15-Minute Resampling
#
# This is the active `preprocess_data` logic. The station filtering block is present in comments in the source, but it is not active. After feature selection, each station is resampled independently to 15-minute intervals using mean aggregation.

# %%
print("========== PREPROCESSING ==========")
print("Original dataset shape:", df.shape)

station_counts = df[STATION_COLUMN].value_counts()
# useful_stations = station_counts[station_counts >= 100].index
# df_filtered = df[df[STATION_COLUMN].isin(useful_stations)]

print("\nDataset shape after station filtering:", df.shape)
print("\nStations available:", sorted(df[STATION_COLUMN].unique().tolist()))

model_df = df_with_time[BASE_FEATURES + [STATION_COLUMN]].copy()

print("\nFeatures used:", BASE_FEATURES)
print("Dataset shape after feature selection:", model_df.shape)

model_df = (
    model_df
    .groupby(STATION_COLUMN)
    .resample("15min")
    .mean()
    .drop(columns=STATION_COLUMN, errors="ignore")
    .reset_index(level=0)
)

model_df = model_df[BASE_FEATURES + [STATION_COLUMN]]

print("\nDataset shape after 15-minute resampling:", model_df.shape)
print("Rows after resampling:", len(model_df))

model_df.head()
# Out:
# ========== PREPROCESSING ==========
# Original dataset shape: (1924653, 20)
#
# Dataset shape after station filtering: (1924653, 20)
#
# Stations available: [1, 2, 3, 4, 5, 6]
#
# Features used: ['ens160_aqi', 'ens160_tvoc', 'bme688_gas_resistance', 'bme688_pressure', 'scd41_temperature', 'scd41_humidity', 'scd41_co2', 'hour_sin', 'hour_cos', 'dayofweek_sin', 'dayofweek_cos', 'is_weekend']
# Dataset shape after feature selection: (1924653, 13)
#
# Dataset shape after 15-minute resampling: (186894, 13)
# Rows after resampling: 186894
# C:\Users\Kenil Dhorajiya\AppData\Local\Temp\ipykernel_18356\3138846357.py:20: FutureWarning: DataFrameGroupBy.resample operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .mean()
#                      ens160_aqi  ens160_tvoc  bme688_gas_resistance  \
# timestamp
# 2024-11-13 16:45:00         1.0    35.000000                    NaN
# 2024-11-13 17:00:00         1.0    26.857143                    NaN
# 2024-11-13 17:15:00         NaN          NaN                    NaN
# 2024-11-13 17:30:00         NaN          NaN                    NaN
# 2024-11-13 17:45:00         NaN          NaN                    NaN
#
#                      bme688_pressure  scd41_temperature  scd41_humidity  \
# timestamp
# 2024-11-13 16:45:00              NaN          22.546857       37.827555
# 2024-11-13 17:00:00              NaN          22.746242       37.604195
# 2024-11-13 17:15:00              NaN                NaN             NaN
# 2024-11-13 17:30:00              NaN                NaN             NaN
# 2024-11-13 17:45:00              NaN                NaN             NaN
#
#                       scd41_co2  hour_sin  hour_cos  dayofweek_sin  \
# timestamp
# 2024-11-13 16:45:00  483.333333 -0.866025 -0.500000       0.974928
# 2024-11-13 17:00:00  472.285714 -0.965926 -0.258819       0.974928
# 2024-11-13 17:15:00         NaN       NaN       NaN            NaN
# 2024-11-13 17:30:00         NaN       NaN       NaN            NaN
# 2024-11-13 17:45:00         NaN       NaN       NaN            NaN
#
#                      dayofweek_cos  is_weekend  station_id
# timestamp
# 2024-11-13 16:45:00      -0.222521         0.0           1
# 2024-11-13 17:00:00      -0.222521         0.0           1
# 2024-11-13 17:15:00            NaN         NaN           1
# 2024-11-13 17:30:00            NaN         NaN           1
# 2024-11-13 17:45:00            NaN         NaN           1

# %% [markdown]
# ## 11. Active Split: Cross-Station Forecasting
#
# The active source code trains on station 3, validates on station 4, and tests on station 5. This is a cross-station experiment, so the test station is unseen during training.

# %%
TRAIN_STATION = 3
VAL_STATION = 4
TEST_STATION = 5

train_df = model_df[model_df[STATION_COLUMN] == TRAIN_STATION].sort_index()
val_df = model_df[model_df[STATION_COLUMN] == VAL_STATION].sort_index()
test_df = model_df[model_df[STATION_COLUMN] == TEST_STATION].sort_index()

print("========== STATION-BASED SPLIT ==========")
print(f"\nTraining Station: {TRAIN_STATION}")
print("Train shape:", train_df.shape)
print(f"\nValidation Station: {VAL_STATION}")
print("Validation shape:", val_df.shape)
print(f"\nTesting Station: {TEST_STATION}")
print("Test shape:", test_df.shape)

train_parts = [train_df]
val_parts = [val_df]
test_parts = [test_df]
# Out:
# ========== STATION-BASED SPLIT ==========
#
# Training Station: 3
# Train shape: (44163, 13)
#
# Validation Station: 4
# Validation shape: (43755, 13)
#
# Testing Station: 5
# Test shape: (29203, 13)

# %% [markdown]
# ### Reference Only: Chronological Split for All Stations
#
# This split exists as commented code in `LSTM.py`. It is included for completeness, but the active notebook workflow uses the cross-station split above.

# %%
# Reference only: not used by the active LSTM pipeline.
#
# train_parts, val_parts, test_parts = [], [], []
# for station_id, station_df in model_df.groupby(STATION_COLUMN):
#     station_df = station_df.sort_index()
#     train_end = int(len(station_df) * 0.70)
#     val_end = int(len(station_df) * 0.85)
#
#     train_parts.append(station_df.iloc[:train_end])
#     val_parts.append(station_df.iloc[train_end:val_end])
#     test_parts.append(station_df.iloc[val_end:])

# %% [markdown]
# ### Reference Only: Leave-One-Station-Out Split
#
# This idea is also present as commented code in the source. It trains on all stations except the selected test station, then takes validation from the final part of the training data.

# %%
# Reference only: not used by the active LSTM pipeline.
#
# def split_data_leave_one_station_out(input_df, test_station):
#     train_df = input_df[input_df[STATION_COLUMN] != test_station].sort_index()
#     test_df = input_df[input_df[STATION_COLUMN] == test_station].sort_index()
#
#     train_end = int(len(train_df) * 0.85)
#     final_train_df = train_df.iloc[:train_end]
#     val_df = train_df.iloc[train_end:]
#
#     train_parts = [final_train_df]
#     val_parts = [val_df]
#     test_parts = [test_df]
#
#     return train_parts, val_parts, test_parts

# %% [markdown]
# ## 12. Fill Missing Values
#
# This matches `fill_missing_parts`. Rows with missing target CO2 are removed. Input features are forward-filled and backward-filled. Remaining missing rows are dropped.

# %%
def fill_missing_parts(parts):
    cleaned_parts = []
    input_features = [col for col in BASE_FEATURES if col != TARGET]

    for i, part in enumerate(parts):
        part = part.copy()

        print(f"\nMissing values BEFORE filling (Part {i + 1}):")
        print(part.isna().sum().sum())

        part = part.dropna(subset=[TARGET])
        part[input_features] = part[input_features].ffill().bfill()

        print(f"Missing values AFTER filling (Part {i + 1}):")
        print(part.isna().sum().sum())

        part = part.dropna()

        if len(part) > 0:
            cleaned_parts.append(part)

    return cleaned_parts

train_parts = fill_missing_parts(train_parts)
val_parts = fill_missing_parts(val_parts)
test_parts = fill_missing_parts(test_parts)

[len(part) for part in train_parts], [len(part) for part in val_parts], [len(part) for part in test_parts]
# Out:
# Missing values BEFORE filling (Part 1):
# 226968
# Missing values AFTER filling (Part 1):
# 0
#
# Missing values BEFORE filling (Part 1):
# 57672
# Missing values AFTER filling (Part 1):
# 0
#
# Missing values BEFORE filling (Part 1):
# 132648
# Missing values AFTER filling (Part 1):
# 0
# ([25249], [38949], [18149])

# %% [markdown]
# ## 13. One-Hot Encode Station IDs
#
# The model does not feed raw `station_id` directly. It creates one-hot station columns for every station ID available after preprocessing and appends those columns to the model features.

# %%
station_ids = sorted(model_df[STATION_COLUMN].unique().tolist())

def build_model_parts(parts, station_ids):
    station_features = [f"station_{station_id}" for station_id in station_ids]
    model_features = BASE_FEATURES + station_features
    model_parts = []

    for part in parts:
        part = part.copy()

        for station_id in station_ids:
            part[f"station_{station_id}"] = (part[STATION_COLUMN] == station_id).astype(int)

        values = part[model_features].values

        if len(values) > 0:
            model_parts.append(values)

    return model_parts, model_features

train_arrays, model_features = build_model_parts(train_parts, station_ids)
val_arrays, _ = build_model_parts(val_parts, station_ids)
test_arrays, _ = build_model_parts(test_parts, station_ids)

print("Station IDs:", station_ids)
print("Model features:", model_features)
print("Number of model features:", len(model_features))
# Out:
# Station IDs: [1, 2, 3, 4, 5, 6]
# Model features: ['ens160_aqi', 'ens160_tvoc', 'bme688_gas_resistance', 'bme688_pressure', 'scd41_temperature', 'scd41_humidity', 'scd41_co2', 'hour_sin', 'hour_cos', 'dayofweek_sin', 'dayofweek_cos', 'is_weekend', 'station_1', 'station_2', 'station_3', 'station_4', 'station_5', 'station_6']
# Number of model features: 18

# %% [markdown]
# ## 14. Scale Data Using Training Data Only
#
# This follows `scale_data`. Fitting the scaler only on the training station prevents validation/test information from leaking into training.

# %%
scaler = MinMaxScaler()
scaler.fit(np.vstack(train_arrays))

print("========== SCALING ==========")
print("MinMaxScaler fitted ONLY on training data")

train_scaled = [scaler.transform(part) for part in train_arrays]
val_scaled = [scaler.transform(part) for part in val_arrays if len(part) > 0]
test_scaled = [scaler.transform(part) for part in test_arrays if len(part) > 0]

train_scaled[0].shape, val_scaled[0].shape, test_scaled[0].shape
# Out:
# ========== SCALING ==========
# MinMaxScaler fitted ONLY on training data
# ((25249, 18), (38949, 18), (18149, 18))

# %% [markdown]
# ## 15. Create Multi-Step Forecasting Sequences
#
# Each sample contains 24 previous rows as input and predicts the next 6 CO2 values. Since the data was resampled to 15-minute intervals, this means 6 hours of history predicting the next 1.5 hours.

# %%
def create_sequences(data_parts, model_features, input_seq_length=24, output_seq_length=6):
    X, y = [], []
    target_index = model_features.index(TARGET)

    for data in data_parts:
        required_length = input_seq_length + output_seq_length

        if len(data) <= required_length:
            print("\nSkipping sequence generation:")
            print(f"Available rows: {len(data)}")
            print(f"Required minimum rows: {required_length + 1}")
            continue

        print("\nOriginal data shape before sequencing:", data.shape)

        for i in range(len(data) - input_seq_length - output_seq_length):
            X.append(data[i:i + input_seq_length])
            y.append(data[i + input_seq_length:i + input_seq_length + output_seq_length, target_index])

    if len(X) == 0:
        raise ValueError("No sequences were created.")

    X = np.array(X)
    y = np.array(y)

    print("Sequence input shape:", X.shape)
    print("Sequence target shape:", y.shape)

    return X, y

X_train, y_train = create_sequences(train_scaled, model_features, INPUT_SEQ_LENGTH, OUTPUT_SEQ_LENGTH)
X_val, y_val = create_sequences(val_scaled, model_features, INPUT_SEQ_LENGTH, OUTPUT_SEQ_LENGTH)
X_test, y_test = create_sequences(test_scaled, model_features, INPUT_SEQ_LENGTH, OUTPUT_SEQ_LENGTH)
# Out:
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)

# %% [markdown]
# ## 16. Create PyTorch DataLoaders
#
# The training loader shuffles samples. Validation and test loaders keep sequence order stable. The original function prints a sample batch shape only when `show_shape=True`.

# %%
def create_loader(X, y, batch_size=32, shuffle=False, show_shape=False):
    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32)

    loader = DataLoader(
        TensorDataset(X_tensor, y_tensor),
        batch_size=batch_size,
        shuffle=shuffle,
    )

    if show_shape:
        sample_X, sample_y = next(iter(loader))
        print("\n========== DATALOADER ==========")
        print("Batch input shape:", sample_X.shape)
        print("Batch target shape:", sample_y.shape)

    return loader

train_loader = create_loader(X_train, y_train, BATCH_SIZE, shuffle=True, show_shape=True)
val_loader = create_loader(X_val, y_val, BATCH_SIZE, shuffle=False)
test_loader = create_loader(X_test, y_test, BATCH_SIZE, shuffle=False)

input_size = X_train.shape[2]
input_size
# Out:
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
# 18

# %% [markdown]
# ## 17. Define the LSTM Model
#
# This is the model from `LSTM.py`. It uses a 2-layer LSTM with hidden size 64, takes the output from the final input timestep, and uses one linear layer to produce all 6 forecast steps.

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, output_seq_length=6, hidden_size=64, num_layers=2):
        super().__init__()

        self.lstm = nn.LSTM(
            input_size,
            hidden_size,
            num_layers,
            batch_first=True,
        )

        self.fc = nn.Linear(hidden_size, output_seq_length)

    def forward(self, x):
        output, _ = self.lstm(x)
        output = output[:, -1, :]
        return self.fc(output)

model = LSTMModel(input_size=input_size, output_seq_length=OUTPUT_SEQ_LENGTH)
model
# Out:
# LSTMModel(
#   (lstm): LSTM(18, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=6, bias=True)
# )

# %% [markdown]
# ## 18. Sanity Check One Forward Pass
#
# Before training, confirm that each input batch produces one 6-step output vector per sample.

# %%
sample_X, sample_y = next(iter(train_loader))
with torch.no_grad():
    sample_predictions = model(sample_X)

print("Sample input shape:", sample_X.shape)
print("Sample target shape:", sample_y.shape)
print("Sample prediction shape:", sample_predictions.shape)
# Out:
# Sample input shape: torch.Size([32, 24, 18])
# Sample target shape: torch.Size([32, 6])
# Sample prediction shape: torch.Size([32, 6])

# %% [markdown]
# ## 19. Training Helpers
#
# These functions keep the original training choices: MSE loss and Adam optimizer with learning rate `0.0001`.

# %%
def evaluate_loss(model, data_loader, criterion):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            predictions = model(X_batch)
            total_loss += criterion(predictions, y_batch).item()

    return total_loss / len(data_loader)


def train_model(model, train_loader, val_loader, epochs=10):
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)

    train_losses, val_losses = [], []

    for epoch in range(epochs):
        model.train()
        train_loss = 0

        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            predictions = model(X_batch)
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss = train_loss / len(train_loader)
        val_loss = evaluate_loss(model, val_loader, criterion)

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        print(
            f"Epoch {epoch + 1}, "
            f"Train Loss: {train_loss:.6f}, "
            f"Val Loss: {val_loss:.6f}"
        )

    return model, train_losses, val_losses

# %% [markdown]
# ## 20. Train the LSTM Model
#
# Run this cell to train. Increase `EPOCHS` in the configuration cell if you want a longer training run.

# %%
model, train_losses, val_losses = train_model(
    model,
    train_loader,
    val_loader,
    epochs=EPOCHS,
)
# Out:
# Epoch 1, Train Loss: 0.012757, Val Loss: 0.010792
# Epoch 2, Train Loss: 0.008170, Val Loss: 0.009569
# Epoch 3, Train Loss: 0.007092, Val Loss: 0.008397
# Epoch 4, Train Loss: 0.005653, Val Loss: 0.008788
# Epoch 5, Train Loss: 0.004717, Val Loss: 0.007948
# Epoch 6, Train Loss: 0.004208, Val Loss: 0.007383
# Epoch 7, Train Loss: 0.003917, Val Loss: 0.006786
# Epoch 8, Train Loss: 0.003737, Val Loss: 0.006709
# Epoch 9, Train Loss: 0.003610, Val Loss: 0.006282
# Epoch 10, Train Loss: 0.003518, Val Loss: 0.006396

# %% [markdown]
# ## 21. Plot Training and Validation Loss
#
# This matches `plot_loss_curves`.

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## 22. Evaluate the Test Station
#
# This follows `evaluate_model`. Overall MSE, MAE, and RMSE are computed by flattening all forecast steps together, exactly like the source file.

# %%
def evaluate_model(model, test_loader):
    model.eval()
    predictions, actuals = [], []

    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            output = model(X_batch)
            predictions.extend(output.numpy())
            actuals.extend(y_batch.numpy())

    predictions = np.array(predictions)
    actuals = np.array(actuals)

    mse = mean_squared_error(actuals.flatten(), predictions.flatten())
    mae = mean_absolute_error(actuals.flatten(), predictions.flatten())
    rmse = np.sqrt(mse)

    print("\n========== MODEL EVALUATION ==========")
    print("Overall MSE:", mse)
    print("Overall MAE:", mae)
    print("Overall RMSE:", rmse)

    return predictions, actuals, mse, mae, rmse

predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)
# Out:
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0018850447377189994
# Overall MAE: 0.027553774416446686
# Overall RMSE: 0.04341710190373143

# %% [markdown]
# ## 23. Optional Per-Step Forecast Metrics
#
# The source contains this idea as commented code. In a notebook, it is useful to see performance separately for forecast steps 1 through 6.

# %%
for step in range(actuals.shape[1]):
    step_mse = mean_squared_error(actuals[:, step], predictions[:, step])
    step_mae = mean_absolute_error(actuals[:, step], predictions[:, step])
    step_rmse = np.sqrt(step_mse)

    print(
        f"Step {step + 1}: "
        f"MSE={step_mse:.6f}, "
        f"MAE={step_mae:.6f}, "
        f"RMSE={step_rmse:.6f}"
    )
# Out:
# Step 1: MSE=0.001647, MAE=0.027786, RMSE=0.040582
# Step 2: MSE=0.002529, MAE=0.039106, RMSE=0.050291
# Step 3: MSE=0.001537, MAE=0.021515, RMSE=0.039208
# Step 4: MSE=0.001952, MAE=0.028885, RMSE=0.044177
# Step 5: MSE=0.001840, MAE=0.024008, RMSE=0.042891
# Step 6: MSE=0.001806, MAE=0.024022, RMSE=0.042494

# %% [markdown]
# ## 24. Plot Actual vs Predicted CO2
#
# This matches `plot_predictions`. It plots one forecast horizon at a time because flattening overlapping multi-step windows can make a misleading plot.

# %%
FORECAST_STEP_TO_PLOT = 1
step_index = FORECAST_STEP_TO_PLOT - 1

plt.figure(figsize=(10, 4))
plt.plot(actuals[:, step_index], label="Actual")
plt.plot(predictions[:, step_index], label="Predicted")
plt.legend()
plt.title(f"Actual vs Predicted CO2 for LSTM (Forecast Step {FORECAST_STEP_TO_PLOT})")
plt.xlabel("Test sequence")
plt.ylabel("Scaled CO2")
plt.show()

# %% [markdown]
# ## 25. Collect Results
#
# This mirrors the dictionary returned by `run_lstm_model`.

# %%
lstm_results = {
    "model": model,
    "predictions": predictions,
    "actuals": actuals,
    "mse": mse,
    "mae": mae,
    "rmse": rmse,
}

lstm_results.keys()
# Out:
# dict_keys(['model', 'predictions', 'actuals', 'mse', 'mae', 'rmse'])

# %% [markdown]
# ## 26. Optional: Save the Trained Model
#
# The original code returns the model but does not save it. This optional cell saves the trained PyTorch weights if needed.

# %%
# Optional save. Uncomment when needed.
# MODEL_OUTPUT_PATH = os.path.join(PROJECT_DIR, "notebooks", "lstm_model.pt")
# torch.save(model.state_dict(), MODEL_OUTPUT_PATH)
# MODEL_OUTPUT_PATH

# %% [markdown]
# ## 27. Compact Function Version
#
# After running the notebook step by step, this helper gives you a compact version similar to `run_pipeline`, using the notebook-defined pieces above.

# %%
def run_notebook_lstm_pipeline(raw_df, epochs=10, input_seq_length=24, output_seq_length=6, batch_size=32):
    prepared = add_time_features(raw_df)
    prepared = prepared[BASE_FEATURES + [STATION_COLUMN]]
    prepared = (
        prepared
        .groupby(STATION_COLUMN)
        .resample("15min")
        .mean()
        .drop(columns=STATION_COLUMN, errors="ignore")
        .reset_index(level=0)
    )
    prepared = prepared[BASE_FEATURES + [STATION_COLUMN]]

    station_ids = sorted(prepared[STATION_COLUMN].unique().tolist())

    train_parts = [prepared[prepared[STATION_COLUMN] == TRAIN_STATION].sort_index()]
    val_parts = [prepared[prepared[STATION_COLUMN] == VAL_STATION].sort_index()]
    test_parts = [prepared[prepared[STATION_COLUMN] == TEST_STATION].sort_index()]

    train_parts = fill_missing_parts(train_parts)
    val_parts = fill_missing_parts(val_parts)
    test_parts = fill_missing_parts(test_parts)

    train_arrays, model_features = build_model_parts(train_parts, station_ids)
    val_arrays, _ = build_model_parts(val_parts, station_ids)
    test_arrays, _ = build_model_parts(test_parts, station_ids)

    scaler = MinMaxScaler()
    scaler.fit(np.vstack(train_arrays))

    train_scaled = [scaler.transform(part) for part in train_arrays]
    val_scaled = [scaler.transform(part) for part in val_arrays if len(part) > 0]
    test_scaled = [scaler.transform(part) for part in test_arrays if len(part) > 0]

    X_train, y_train = create_sequences(train_scaled, model_features, input_seq_length, output_seq_length)
    X_val, y_val = create_sequences(val_scaled, model_features, input_seq_length, output_seq_length)
    X_test, y_test = create_sequences(test_scaled, model_features, input_seq_length, output_seq_length)

    train_loader = create_loader(X_train, y_train, batch_size, shuffle=True, show_shape=True)
    val_loader = create_loader(X_val, y_val, batch_size, shuffle=False)
    test_loader = create_loader(X_test, y_test, batch_size, shuffle=False)

    model = LSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
    model, train_losses, val_losses = train_model(model, train_loader, val_loader, epochs=epochs)
    predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)

    return {
        "model": model,
        "predictions": predictions,
        "actuals": actuals,
        "mse": mse,
        "mae": mae,
        "rmse": rmse,
        "train_losses": train_losses,
        "val_losses": val_losses,
    }

# %%
## 11111111

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Force Jupyter to display matplotlib plots directly inside the notebook inline
# %matplotlib inline

global TARGET, model_features

# ==========================================
# 1. PIPELINE FUNCTION WRAPPER
# ==========================================
def run_pipeline(target_feature, output_seq_length, epochs=10):
    global TARGET, model_features
    TARGET = target_feature 
    input_seq_length = 24  
    batch_size = 32
    
    X_train, y_train = create_sequences(train_scaled, model_features, input_seq_length, output_seq_length)
    X_val, y_val = create_sequences(val_scaled, model_features, input_seq_length, output_seq_length)
    X_test, y_test = create_sequences(test_scaled, model_features, input_seq_length, output_seq_length)
    
    train_loader = create_loader(X_train, y_train, batch_size, shuffle=True)
    val_loader = create_loader(X_val, y_val, batch_size, shuffle=False)
    test_loader = create_loader(X_test, y_test, batch_size, shuffle=False)
    
    # Dynamically switches based on whether you are running the LSTM or CNNLSTM notebook
    if 'CNNLSTMModel' in globals():
        model = CNNLSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
    else:
        model = LSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
        
    model, train_losses, val_losses = train_model(model, train_loader, val_loader, epochs=epochs)
    predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)
    
    return {
        "predictions": predictions,
        "actuals": actuals,
        "train_losses": train_losses,
        "val_losses": val_losses
    }

# ==========================================
# 2. MASTER EXPERIMENT LOOP (SILENT TRAINING)
# ==========================================
output_lengths = [1, 6, 12, 24, 48]
target_features = [
    "ens160_aqi", 
    "ens160_tvoc", 
    "scd41_temperature", 
    "scd41_humidity", 
    "scd41_co2"
]

# This list holds all plots until the very end
all_plots_storage = []

print("Starting automation run... Training all models first. Please wait...")

for target in target_features:
    for out_len in output_lengths:
        print(f"Running background training for: {target} (Len: {out_len})")
        try:
            results = run_pipeline(
                target_feature=target, 
                output_seq_length=out_len,
                epochs=10
            )
            
            # Extract target lines for predictions
            if out_len > 1:
                plot_actuals = results["actuals"][:200, 0]
                plot_preds = results["predictions"][:200, 0]
            else:
                plot_actuals = results["actuals"][:200].flatten()
                plot_preds = results["predictions"][:200].flatten()
            
            # Store Loss Plot data
            all_plots_storage.append({
                "type": "loss",
                "title": f"Loss: {target} (Len: {out_len})",
                "data1": results["train_losses"],
                "data2": results["val_losses"],
                "label1": "Train Loss",
                "label2": "Val Loss"
            })
            
            # Store Prediction Plot data
            all_plots_storage.append({
                "type": "pred",
                "title": f"Pred: {target} (Len: {out_len})",
                "data1": plot_actuals,
                "data2": plot_preds,
                "label1": "Actual",
                "label2": "Predicted"
            })
            
        except Exception as e:
            print(f"Error during training [{target} | Length {out_len}]: {e}")

# ==========================================
# 3. SHOW ALL RESULTS AT THE VERY END (4 PER ROW)
# ==========================================
print("\n" + "="*60)
print(" TRAINING COMPLETE! Showing all results below:")
print("="*60 + "\n")

plots_per_row = 4
total_plots = len(all_plots_storage)

# Loop over the stored items 4 at a time to build rows
for i in range(0, total_plots, plots_per_row):
    current_chunk = all_plots_storage[i : i + plots_per_row]
    num_cols = len(current_chunk)
    
    # Create a clean horizontal grid row
    fig, axes = plt.subplots(1, plots_per_row, figsize=(24, 5))
    
    # Fallback handle if only 1 plot is left at the end
    if plots_per_row == 1:
        axes = [axes]
        
    for col_idx in range(plots_per_row):
        ax = axes[col_idx]
        
        if col_idx < num_cols:
            item = current_chunk[col_idx]
            
            # Plot data lines
            ax.plot(item["data1"], label=item["label1"], color="blue", alpha=0.7)
            ax.plot(item["data2"], label=item["label2"], color="orange", alpha=0.8)
            ax.set_title(item["title"], fontsize=11, fontweight="bold")
            ax.legend(loc="upper right")
            ax.grid(True, linestyle="--", alpha=0.5)
            
            if item["type"] == "loss":
                ax.set_xlabel("Epochs")
                ax.set_ylabel("Loss Value")
            else:
                ax.set_xlabel("Time Steps")
                ax.set_ylabel("Scaled Value")
        else:
            # Hide blank remaining plot boxes
            ax.axis('off')
            
    plt.tight_layout()
    plt.show() # Shows this row of 4 graphs together instantly

print("\n DONE! Every single model graph has been printed above.")
# Out:
# Starting automation run... Training all models first. Please wait...
# Running background training for: ens160_aqi (Len: 1)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.004794, Val Loss: 0.003691
# Epoch 2, Train Loss: 0.003422, Val Loss: 0.003064
# Epoch 3, Train Loss: 0.002960, Val Loss: 0.002553
# Epoch 4, Train Loss: 0.002368, Val Loss: 0.002043
# Epoch 5, Train Loss: 0.001608, Val Loss: 0.001720
# Epoch 6, Train Loss: 0.001222, Val Loss: 0.001515
# Epoch 7, Train Loss: 0.001069, Val Loss: 0.001435
# Epoch 8, Train Loss: 0.000964, Val Loss: 0.001555
# Epoch 9, Train Loss: 0.000879, Val Loss: 0.001627
# Epoch 10, Train Loss: 0.000809, Val Loss: 0.001748
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0032598888501524925
# Overall MAE: 0.04789555072784424
# Overall RMSE: 0.05709543633384802
# Running background training for: ens160_aqi (Len: 6)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.015154, Val Loss: 0.003548
# Epoch 2, Train Loss: 0.003476, Val Loss: 0.003350
# Epoch 3, Train Loss: 0.003101, Val Loss: 0.003481
# Epoch 4, Train Loss: 0.002794, Val Loss: 0.003583
# Epoch 5, Train Loss: 0.002454, Val Loss: 0.003696
# Epoch 6, Train Loss: 0.002067, Val Loss: 0.003612
# Epoch 7, Train Loss: 0.001755, Val Loss: 0.003891
# Epoch 8, Train Loss: 0.001575, Val Loss: 0.004043
# Epoch 9, Train Loss: 0.001447, Val Loss: 0.004137
# Epoch 10, Train Loss: 0.001348, Val Loss: 0.005386
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0030371034517884254
# Overall MAE: 0.04217406362295151
# Overall RMSE: 0.05510992153676528
# Running background training for: ens160_aqi (Len: 12)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.016741, Val Loss: 0.004319
# Epoch 2, Train Loss: 0.003676, Val Loss: 0.003177
# Epoch 3, Train Loss: 0.003165, Val Loss: 0.002803
# Epoch 4, Train Loss: 0.002732, Val Loss: 0.002500
# Epoch 5, Train Loss: 0.002335, Val Loss: 0.002343
# Epoch 6, Train Loss: 0.002038, Val Loss: 0.002345
# Epoch 7, Train Loss: 0.001846, Val Loss: 0.002343
# Epoch 8, Train Loss: 0.001712, Val Loss: 0.002452
# Epoch 9, Train Loss: 0.001608, Val Loss: 0.002511
# Epoch 10, Train Loss: 0.001524, Val Loss: 0.002447
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.007281406782567501
# Overall MAE: 0.07273180037736893
# Overall RMSE: 0.08533115950558448
# Running background training for: ens160_aqi (Len: 24)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
# Epoch 1, Train Loss: 0.018506, Val Loss: 0.007685
# Epoch 2, Train Loss: 0.004298, Val Loss: 0.003314
# Epoch 3, Train Loss: 0.003233, Val Loss: 0.003052
# Epoch 4, Train Loss: 0.002952, Val Loss: 0.002945
# Epoch 5, Train Loss: 0.002655, Val Loss: 0.003059
# Epoch 6, Train Loss: 0.002347, Val Loss: 0.003810
# Epoch 7, Train Loss: 0.002119, Val Loss: 0.004511
# Epoch 8, Train Loss: 0.001983, Val Loss: 0.005166
# Epoch 9, Train Loss: 0.001893, Val Loss: 0.005744
# Epoch 10, Train Loss: 0.001825, Val Loss: 0.005687
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.007640209048986435
# Overall MAE: 0.0732448473572731
# Overall RMSE: 0.08740828936082913
# Running background training for: ens160_aqi (Len: 48)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
# Epoch 1, Train Loss: 0.016028, Val Loss: 0.006898
# Epoch 2, Train Loss: 0.004108, Val Loss: 0.003535
# Epoch 3, Train Loss: 0.003458, Val Loss: 0.003314
# Epoch 4, Train Loss: 0.003240, Val Loss: 0.003071
# Epoch 5, Train Loss: 0.003006, Val Loss: 0.002992
# Epoch 6, Train Loss: 0.002729, Val Loss: 0.003029
# Epoch 7, Train Loss: 0.002468, Val Loss: 0.003431
# Epoch 8, Train Loss: 0.002308, Val Loss: 0.004248
# Epoch 9, Train Loss: 0.002217, Val Loss: 0.004573
# Epoch 10, Train Loss: 0.002156, Val Loss: 0.004922
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0030683488585054874
# Overall MAE: 0.041949376463890076
# Overall RMSE: 0.05539267874462732
# Running background training for: ens160_tvoc (Len: 1)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.001657, Val Loss: 0.001860
# Epoch 2, Train Loss: 0.001404, Val Loss: 0.001791
# Epoch 3, Train Loss: 0.001329, Val Loss: 0.001728
# Epoch 4, Train Loss: 0.001250, Val Loss: 0.001659
# Epoch 5, Train Loss: 0.001165, Val Loss: 0.001595
# Epoch 6, Train Loss: 0.001080, Val Loss: 0.001525
# Epoch 7, Train Loss: 0.000998, Val Loss: 0.001411
# Epoch 8, Train Loss: 0.000915, Val Loss: 0.001274
# Epoch 9, Train Loss: 0.000819, Val Loss: 0.001142
# Epoch 10, Train Loss: 0.000716, Val Loss: 0.000957
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.00653938390314579
# Overall MAE: 0.0729367807507515
# Overall RMSE: 0.0808664572189594
# Running background training for: ens160_tvoc (Len: 6)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.002311, Val Loss: 0.002041
# Epoch 2, Train Loss: 0.001501, Val Loss: 0.002021
# Epoch 3, Train Loss: 0.001448, Val Loss: 0.002059
# Epoch 4, Train Loss: 0.001406, Val Loss: 0.002110
# Epoch 5, Train Loss: 0.001366, Val Loss: 0.002306
# Epoch 6, Train Loss: 0.001309, Val Loss: 0.002619
# Epoch 7, Train Loss: 0.001248, Val Loss: 0.003438
# Epoch 8, Train Loss: 0.001180, Val Loss: 0.004403
# Epoch 9, Train Loss: 0.001101, Val Loss: 0.005678
# Epoch 10, Train Loss: 0.000997, Val Loss: 0.006816
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0017018516082316637
# Overall MAE: 0.01657010428607464
# Overall RMSE: 0.04125350419336112
# Running background training for: ens160_tvoc (Len: 12)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.003847, Val Loss: 0.002409
# Epoch 2, Train Loss: 0.001551, Val Loss: 0.002173
# Epoch 3, Train Loss: 0.001501, Val Loss: 0.002153
# Epoch 4, Train Loss: 0.001461, Val Loss: 0.002159
# Epoch 5, Train Loss: 0.001426, Val Loss: 0.002179
# Epoch 6, Train Loss: 0.001389, Val Loss: 0.002201
# Epoch 7, Train Loss: 0.001345, Val Loss: 0.002374
# Epoch 8, Train Loss: 0.001288, Val Loss: 0.002531
# Epoch 9, Train Loss: 0.001207, Val Loss: 0.002980
# Epoch 10, Train Loss: 0.001098, Val Loss: 0.003731
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.002538191620260477
# Overall MAE: 0.030798055231571198
# Overall RMSE: 0.05038046863875402
# Running background training for: ens160_tvoc (Len: 24)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
# Epoch 1, Train Loss: 0.003405, Val Loss: 0.001833
# Epoch 2, Train Loss: 0.001579, Val Loss: 0.001660
# Epoch 3, Train Loss: 0.001524, Val Loss: 0.001610
# Epoch 4, Train Loss: 0.001493, Val Loss: 0.001577
# Epoch 5, Train Loss: 0.001465, Val Loss: 0.001575
# Epoch 6, Train Loss: 0.001438, Val Loss: 0.001556
# Epoch 7, Train Loss: 0.001408, Val Loss: 0.001554
# Epoch 8, Train Loss: 0.001368, Val Loss: 0.001569
# Epoch 9, Train Loss: 0.001320, Val Loss: 0.001559
# Epoch 10, Train Loss: 0.001266, Val Loss: 0.001614
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.002166664693504572
# Overall MAE: 0.01915786787867546
# Overall RMSE: 0.04654744561739744
# Running background training for: ens160_tvoc (Len: 48)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
# Epoch 1, Train Loss: 0.004041, Val Loss: 0.001582
# Epoch 2, Train Loss: 0.001654, Val Loss: 0.001225
# Epoch 3, Train Loss: 0.001545, Val Loss: 0.001182
# Epoch 4, Train Loss: 0.001519, Val Loss: 0.001156
# Epoch 5, Train Loss: 0.001497, Val Loss: 0.001137
# Epoch 6, Train Loss: 0.001474, Val Loss: 0.001140
# Epoch 7, Train Loss: 0.001450, Val Loss: 0.001129
# Epoch 8, Train Loss: 0.001420, Val Loss: 0.001110
# Epoch 9, Train Loss: 0.001387, Val Loss: 0.001116
# Epoch 10, Train Loss: 0.001349, Val Loss: 0.001062
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.002145836129784584
# Overall MAE: 0.016079293563961983
# Overall RMSE: 0.04632317054978625
# Running background training for: scd41_temperature (Len: 1)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.136415, Val Loss: 0.029026
# Epoch 2, Train Loss: 0.019148, Val Loss: 0.028799
# Epoch 3, Train Loss: 0.014497, Val Loss: 0.020423
# Epoch 4, Train Loss: 0.010069, Val Loss: 0.012570
# Epoch 5, Train Loss: 0.006464, Val Loss: 0.008229
# Epoch 6, Train Loss: 0.004292, Val Loss: 0.006589
# Epoch 7, Train Loss: 0.003295, Val Loss: 0.005941
# Epoch 8, Train Loss: 0.002819, Val Loss: 0.006377
# Epoch 9, Train Loss: 0.002534, Val Loss: 0.006686
# Epoch 10, Train Loss: 0.002335, Val Loss: 0.007162
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.011159297078847885
# Overall MAE: 0.08846715092658997
# Overall RMSE: 0.10563757418100761
# Running background training for: scd41_temperature (Len: 6)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.233828, Val Loss: 0.025587
# Epoch 2, Train Loss: 0.021249, Val Loss: 0.032801
# Epoch 3, Train Loss: 0.016497, Val Loss: 0.023782
# Epoch 4, Train Loss: 0.011892, Val Loss: 0.010447
# Epoch 5, Train Loss: 0.007137, Val Loss: 0.009295
# Epoch 6, Train Loss: 0.005569, Val Loss: 0.010552
# Epoch 7, Train Loss: 0.004852, Val Loss: 0.013251
# Epoch 8, Train Loss: 0.004400, Val Loss: 0.015455
# Epoch 9, Train Loss: 0.004080, Val Loss: 0.016318
# Epoch 10, Train Loss: 0.003839, Val Loss: 0.017892
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.07090630382299423
# Overall MAE: 0.23953741788864136
# Overall RMSE: 0.26628237610287736
# Running background training for: scd41_temperature (Len: 12)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.239935, Val Loss: 0.036467
# Epoch 2, Train Loss: 0.022171, Val Loss: 0.035223
# Epoch 3, Train Loss: 0.016283, Val Loss: 0.028149
# Epoch 4, Train Loss: 0.012443, Val Loss: 0.013951
# Epoch 5, Train Loss: 0.008085, Val Loss: 0.008588
# Epoch 6, Train Loss: 0.006438, Val Loss: 0.007113
# Epoch 7, Train Loss: 0.005686, Val Loss: 0.006489
# Epoch 8, Train Loss: 0.005255, Val Loss: 0.006268
# Epoch 9, Train Loss: 0.004967, Val Loss: 0.006200
# Epoch 10, Train Loss: 0.004757, Val Loss: 0.005940
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.01894695870578289
# Overall MAE: 0.11414296180009842
# Overall RMSE: 0.1376479520580778
# Running background training for: scd41_temperature (Len: 24)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
# Epoch 1, Train Loss: 0.318352, Val Loss: 0.060767
# Epoch 2, Train Loss: 0.030687, Val Loss: 0.031537
# Epoch 3, Train Loss: 0.016375, Val Loss: 0.027363
# Epoch 4, Train Loss: 0.013812, Val Loss: 0.017833
# Epoch 5, Train Loss: 0.010019, Val Loss: 0.011157
# Epoch 6, Train Loss: 0.007797, Val Loss: 0.009567
# Epoch 7, Train Loss: 0.006838, Val Loss: 0.008234
# Epoch 8, Train Loss: 0.006249, Val Loss: 0.007362
# Epoch 9, Train Loss: 0.005861, Val Loss: 0.006985
# Epoch 10, Train Loss: 0.005613, Val Loss: 0.006725
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0185747928917408
# Overall MAE: 0.10888484120368958
# Overall RMSE: 0.1362893718957601
# Running background training for: scd41_temperature (Len: 48)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
# Epoch 1, Train Loss: 0.267114, Val Loss: 0.057400
# Epoch 2, Train Loss: 0.030751, Val Loss: 0.052092
# Epoch 3, Train Loss: 0.017215, Val Loss: 0.050581
# Epoch 4, Train Loss: 0.014588, Val Loss: 0.045813
# Epoch 5, Train Loss: 0.010464, Val Loss: 0.047915
# Epoch 6, Train Loss: 0.008662, Val Loss: 0.051779
# Epoch 7, Train Loss: 0.007939, Val Loss: 0.047826
# Epoch 8, Train Loss: 0.007463, Val Loss: 0.045952
# Epoch 9, Train Loss: 0.007093, Val Loss: 0.043717
# Epoch 10, Train Loss: 0.006795, Val Loss: 0.039392
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.01205721590667963
# Overall MAE: 0.08380956947803497
# Overall RMSE: 0.10980535463573546
# Running background training for: scd41_humidity (Len: 1)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.071318, Val Loss: 0.036824
# Epoch 2, Train Loss: 0.020633, Val Loss: 0.030835
# Epoch 3, Train Loss: 0.015664, Val Loss: 0.023432
# Epoch 4, Train Loss: 0.007617, Val Loss: 0.008778
# Epoch 5, Train Loss: 0.003567, Val Loss: 0.020711
# Epoch 6, Train Loss: 0.002789, Val Loss: 0.027738
# Epoch 7, Train Loss: 0.002330, Val Loss: 0.032696
# Epoch 8, Train Loss: 0.001962, Val Loss: 0.037693
# Epoch 9, Train Loss: 0.001665, Val Loss: 0.041476
# Epoch 10, Train Loss: 0.001431, Val Loss: 0.043144
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.01776891015470028
# Overall MAE: 0.12383691221475601
# Overall RMSE: 0.13330007559900436
# Running background training for: scd41_humidity (Len: 6)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.138033, Val Loss: 0.051217
# Epoch 2, Train Loss: 0.024075, Val Loss: 0.036607
# Epoch 3, Train Loss: 0.018744, Val Loss: 0.036454
# Epoch 4, Train Loss: 0.010586, Val Loss: 0.030338
# Epoch 5, Train Loss: 0.004732, Val Loss: 0.012319
# Epoch 6, Train Loss: 0.003418, Val Loss: 0.006037
# Epoch 7, Train Loss: 0.002871, Val Loss: 0.004048
# Epoch 8, Train Loss: 0.002489, Val Loss: 0.003687
# Epoch 9, Train Loss: 0.002230, Val Loss: 0.003760
# Epoch 10, Train Loss: 0.002052, Val Loss: 0.004058
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.018922045826911926
# Overall MAE: 0.12027660012245178
# Overall RMSE: 0.13755742737821147
# Running background training for: scd41_humidity (Len: 12)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.120246, Val Loss: 0.068852
# Epoch 2, Train Loss: 0.026531, Val Loss: 0.044339
# Epoch 3, Train Loss: 0.019175, Val Loss: 0.058233
# Epoch 4, Train Loss: 0.010654, Val Loss: 0.079163
# Epoch 5, Train Loss: 0.005121, Val Loss: 0.078004
# Epoch 6, Train Loss: 0.003857, Val Loss: 0.077598
# Epoch 7, Train Loss: 0.003260, Val Loss: 0.072327
# Epoch 8, Train Loss: 0.002882, Val Loss: 0.073656
# Epoch 9, Train Loss: 0.002638, Val Loss: 0.072741
# Epoch 10, Train Loss: 0.002476, Val Loss: 0.071117
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.04238104820251465
# Overall MAE: 0.1865702122449875
# Overall RMSE: 0.20586657864382613
# Running background training for: scd41_humidity (Len: 24)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
# Epoch 1, Train Loss: 0.145358, Val Loss: 0.096226
# Epoch 2, Train Loss: 0.027723, Val Loss: 0.042180
# Epoch 3, Train Loss: 0.018662, Val Loss: 0.051791
# Epoch 4, Train Loss: 0.009188, Val Loss: 0.061706
# Epoch 5, Train Loss: 0.004646, Val Loss: 0.048612
# Epoch 6, Train Loss: 0.003876, Val Loss: 0.040117
# Epoch 7, Train Loss: 0.003515, Val Loss: 0.039718
# Epoch 8, Train Loss: 0.003292, Val Loss: 0.038102
# Epoch 9, Train Loss: 0.003145, Val Loss: 0.035879
# Epoch 10, Train Loss: 0.003039, Val Loss: 0.033977
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.05457427352666855
# Overall MAE: 0.21178369224071503
# Overall RMSE: 0.23361137285386718
# Running background training for: scd41_humidity (Len: 48)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
# Epoch 1, Train Loss: 0.139475, Val Loss: 0.090965
# Epoch 2, Train Loss: 0.028646, Val Loss: 0.057599
# Epoch 3, Train Loss: 0.015312, Val Loss: 0.081374
# Epoch 4, Train Loss: 0.008153, Val Loss: 0.069645
# Epoch 5, Train Loss: 0.006333, Val Loss: 0.057750
# Epoch 6, Train Loss: 0.005602, Val Loss: 0.047535
# Epoch 7, Train Loss: 0.005100, Val Loss: 0.042536
# Epoch 8, Train Loss: 0.004730, Val Loss: 0.035578
# Epoch 9, Train Loss: 0.004455, Val Loss: 0.031390
# Epoch 10, Train Loss: 0.004250, Val Loss: 0.029270
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.07449721544981003
# Overall MAE: 0.2465943545103073
# Overall RMSE: 0.2729417803301833
# Running background training for: scd41_co2 (Len: 1)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.008736, Val Loss: 0.009555
# Epoch 2, Train Loss: 0.007288, Val Loss: 0.011433
# Epoch 3, Train Loss: 0.005850, Val Loss: 0.022009
# Epoch 4, Train Loss: 0.004141, Val Loss: 0.040298
# Epoch 5, Train Loss: 0.003151, Val Loss: 0.044370
# Epoch 6, Train Loss: 0.002837, Val Loss: 0.039955
# Epoch 7, Train Loss: 0.002667, Val Loss: 0.037558
# Epoch 8, Train Loss: 0.002539, Val Loss: 0.036202
# Epoch 9, Train Loss: 0.002432, Val Loss: 0.035266
# Epoch 10, Train Loss: 0.002330, Val Loss: 0.035040
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0030975008849054575
# Overall MAE: 0.04477137699723244
# Overall RMSE: 0.0556551963872688
# Running background training for: scd41_co2 (Len: 6)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.012861, Val Loss: 0.010218
# Epoch 2, Train Loss: 0.008293, Val Loss: 0.009831
# Epoch 3, Train Loss: 0.007212, Val Loss: 0.013405
# Epoch 4, Train Loss: 0.006173, Val Loss: 0.019077
# Epoch 5, Train Loss: 0.005268, Val Loss: 0.023685
# Epoch 6, Train Loss: 0.004423, Val Loss: 0.021621
# Epoch 7, Train Loss: 0.003954, Val Loss: 0.021140
# Epoch 8, Train Loss: 0.003775, Val Loss: 0.021882
# Epoch 9, Train Loss: 0.003659, Val Loss: 0.021589
# Epoch 10, Train Loss: 0.003577, Val Loss: 0.022178
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.004049733746796846
# Overall MAE: 0.048958782106637955
# Overall RMSE: 0.06363751838967989
# Running background training for: scd41_co2 (Len: 12)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.012968, Val Loss: 0.010576
# Epoch 2, Train Loss: 0.008075, Val Loss: 0.009526
# Epoch 3, Train Loss: 0.007290, Val Loss: 0.008746
# Epoch 4, Train Loss: 0.006421, Val Loss: 0.008087
# Epoch 5, Train Loss: 0.005726, Val Loss: 0.007422
# Epoch 6, Train Loss: 0.005101, Val Loss: 0.007059
# Epoch 7, Train Loss: 0.004647, Val Loss: 0.007106
# Epoch 8, Train Loss: 0.004413, Val Loss: 0.007316
# Epoch 9, Train Loss: 0.004283, Val Loss: 0.007053
# Epoch 10, Train Loss: 0.004195, Val Loss: 0.007046
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0047332849353551865
# Overall MAE: 0.04972170293331146
# Overall RMSE: 0.06879887306747973
# Running background training for: scd41_co2 (Len: 24)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
# Epoch 1, Train Loss: 0.011695, Val Loss: 0.010569
# Epoch 2, Train Loss: 0.008403, Val Loss: 0.009552
# Epoch 3, Train Loss: 0.007642, Val Loss: 0.009571
# Epoch 4, Train Loss: 0.006753, Val Loss: 0.010282
# Epoch 5, Train Loss: 0.006052, Val Loss: 0.009871
# Epoch 6, Train Loss: 0.005424, Val Loss: 0.008953
# Epoch 7, Train Loss: 0.005037, Val Loss: 0.008645
# Epoch 8, Train Loss: 0.004874, Val Loss: 0.007779
# Epoch 9, Train Loss: 0.004785, Val Loss: 0.008197
# Epoch 10, Train Loss: 0.004726, Val Loss: 0.007614
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.002358080353587866
# Overall MAE: 0.029645536094903946
# Overall RMSE: 0.04856006953854026
# Running background training for: scd41_co2 (Len: 48)
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
# Epoch 1, Train Loss: 0.013789, Val Loss: 0.011435
# Epoch 2, Train Loss: 0.008528, Val Loss: 0.010030
# Epoch 3, Train Loss: 0.007915, Val Loss: 0.010542
# Epoch 4, Train Loss: 0.007413, Val Loss: 0.010748
# Epoch 5, Train Loss: 0.006907, Val Loss: 0.010999
# Epoch 6, Train Loss: 0.006502, Val Loss: 0.010300
# Epoch 7, Train Loss: 0.006183, Val Loss: 0.008816
# Epoch 8, Train Loss: 0.005961, Val Loss: 0.008136
# Epoch 9, Train Loss: 0.005818, Val Loss: 0.007925
# Epoch 10, Train Loss: 0.005728, Val Loss: 0.007621
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.003237747820094228
# Overall MAE: 0.03272242844104767
# Overall RMSE: 0.05690121105999615
#
# ============================================================
#  TRAINING COMPLETE! Showing all results below:
# ============================================================
#  DONE! Every single model graph has been printed above.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

global TARGET, model_features

# ==========================================
# 1. LSTM PIPELINE FUNCTION WRAPPER
# ==========================================
def run_pipeline(target_feature, output_seq_length, epochs=10):
    global TARGET, model_features
    TARGET = target_feature 
    input_seq_length = 24  # 6 hours lookback history
    batch_size = 32
    
    # --- Step A: Sequence Creation ---
    X_train, y_train = create_sequences(train_scaled, model_features, input_seq_length, output_seq_length)
    X_val, y_val = create_sequences(val_scaled, model_features, input_seq_length, output_seq_length)
    X_test, y_test = create_sequences(test_scaled, model_features, input_seq_length, output_seq_length)
    
    # --- Step B: Data Loaders ---
    train_loader = create_loader(X_train, y_train, batch_size, shuffle=True)
    val_loader = create_loader(X_val, y_val, batch_size, shuffle=False)
    test_loader = create_loader(X_test, y_test, batch_size, shuffle=False)
    
    # --- Step C: Initialize standard LSTM Model ---
    model = LSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
    
    # --- Step D: Train Model (Runs at optimal lr=0.001) ---
    model, train_losses, val_losses = train_model(model, train_loader, val_loader, epochs=epochs)
    
    # --- Step E: Evaluate Model ---
    predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)
    
    return {
        "predictions": predictions,
        "actuals": actuals,
        "mse": mse,
        "mae": mae,
        "rmse": rmse,
        "train_losses": train_losses,
        "val_losses": val_losses
    }

# ==========================================
# 2. MASTER AUTOMATION LOOP
# ==========================================
output_lengths = [1, 6, 12]
target_features = [
    "ens160_aqi", 
    "ens160_tvoc", 
    "scd41_temperature", 
    "scd41_humidity", 
    "scd41_co2"
]

all_results_summary = []
output_base_dir = "lstm_experiment_results"
os.makedirs(output_base_dir, exist_ok=True)

print("Starting standard LSTM automation run with clean 2-line plotting logic...")

for target in target_features:
    for out_len in output_lengths:
        print("\n" + "="*50)
        print(f"RUNNING LSTM EXPERIMENT: Target = {target} | Output Length = {out_len}")
        print("="*50)
        
        try:
            results = run_pipeline(
                target_feature=target, 
                output_seq_length=out_len,
                epochs=10
            )
            
            # Record key error metrics: MSE, MAE, RMSE
            all_results_summary.append({
                "Target_Feature": target,
                "Output_Length": out_len,
                "MSE": results["mse"],
                "MAE": results["mae"],
                "RMSE": results["rmse"]
            })
            
            # ------------------------------------------
            # GRAPH 1: Clean Actual vs Predicted (Exactly Two Lines)
            # ------------------------------------------
            plt.figure(figsize=(12, 6))
            
            # Flattening out the timeline slice to avoid multi-line window overlaps
            if out_len > 1:
                plot_actuals = results["actuals"][:200, 0]
                plot_preds = results["predictions"][:200, 0]
            else:
                plot_actuals = results["actuals"][:200].flatten()
                plot_preds = results["predictions"][:200].flatten()
                
            plt.plot(plot_actuals, label="Actual", color="blue", alpha=0.7)
            plt.plot(plot_preds, label="Predicted", color="orange", alpha=0.8)
            
            plt.title(f"LSTM Predictions vs Actuals - {target} (Len: {out_len})")
            plt.xlabel("Time Steps")
            plt.ylabel("Scaled Value")
            plt.legend()
            
            plot_filename = f"{output_base_dir}/plot_{target}_len_{out_len}.png"
            plt.savefig(plot_filename)
            plt.close()
            
            # ------------------------------------------
            # GRAPH 2: Training & Validation Loss Plot
            # ------------------------------------------
            plt.figure(figsize=(12, 6))
            plt.plot(results["train_losses"], label="Train Loss", color="blue")
            plt.plot(results["val_losses"], label="Validation Loss", color="orange")
            plt.title(f"LSTM Model Loss Over Epochs - {target} (Len: {out_len})")
            plt.xlabel("Epochs")
            plt.ylabel("Loss")
            plt.legend()
            
            loss_filename = f"{output_base_dir}/loss_{target}_len_{out_len}.png"
            plt.savefig(loss_filename)
            plt.close()
            
            print(f"Success! Clean 2-line graphs saved for LSTM {target} (len={out_len})")
            
        except Exception as e:
            print(f"Error during experiment [{target} | Length {out_len}]: {e}")

# ==========================================
# 3. EXPORT EXCEL/CSV SHEET
# ==========================================
if all_results_summary:
    df_summary = pd.DataFrame(all_results_summary)
    summary_path = f"{output_base_dir}/master_metrics_summary.csv"
    df_summary.to_csv(summary_path, index=False)
    print(f"\nDONE! All 15 standard LSTM variants computed successfully. View results folder: '{output_base_dir}'")
else:
    print("\nLoop execution failed. Review errors above.")
# Out:
# Starting standard LSTM automation run with clean 2-line plotting logic...
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = ens160_aqi | Output Length = 1
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.003563, Val Loss: 0.002098
# Epoch 2, Train Loss: 0.000898, Val Loss: 0.002754
# Epoch 3, Train Loss: 0.000613, Val Loss: 0.001512
# Epoch 4, Train Loss: 0.000497, Val Loss: 0.001137
# Epoch 5, Train Loss: 0.000442, Val Loss: 0.000911
# Epoch 6, Train Loss: 0.000392, Val Loss: 0.000591
# Epoch 7, Train Loss: 0.000355, Val Loss: 0.000509
# Epoch 8, Train Loss: 0.000322, Val Loss: 0.000369
# Epoch 9, Train Loss: 0.000293, Val Loss: 0.000339
# Epoch 10, Train Loss: 0.000270, Val Loss: 0.000314
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.01060078851878643
# Overall MAE: 0.10051436722278595
# Overall RMSE: 0.10296013072440434
# Success! Clean 2-line graphs saved for LSTM ens160_aqi (len=1)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = ens160_aqi | Output Length = 6
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.004693, Val Loss: 0.011485
# Epoch 2, Train Loss: 0.001153, Val Loss: 0.012623
# Epoch 3, Train Loss: 0.000911, Val Loss: 0.011339
# Epoch 4, Train Loss: 0.000831, Val Loss: 0.014328
# Epoch 5, Train Loss: 0.000779, Val Loss: 0.012682
# Epoch 6, Train Loss: 0.000757, Val Loss: 0.012917
# Epoch 7, Train Loss: 0.000726, Val Loss: 0.012290
# Epoch 8, Train Loss: 0.000688, Val Loss: 0.012075
# Epoch 9, Train Loss: 0.000667, Val Loss: 0.012512
# Epoch 10, Train Loss: 0.000654, Val Loss: 0.009558
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.01095664408057928
# Overall MAE: 0.09924846142530441
# Overall RMSE: 0.10467398951305563
# Success! Clean 2-line graphs saved for LSTM ens160_aqi (len=6)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = ens160_aqi | Output Length = 12
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.002958, Val Loss: 0.002387
# Epoch 2, Train Loss: 0.001283, Val Loss: 0.002711
# Epoch 3, Train Loss: 0.001104, Val Loss: 0.002759
# Epoch 4, Train Loss: 0.001028, Val Loss: 0.002192
# Epoch 5, Train Loss: 0.000989, Val Loss: 0.002121
# Epoch 6, Train Loss: 0.000959, Val Loss: 0.002242
# Epoch 7, Train Loss: 0.000930, Val Loss: 0.002373
# Epoch 8, Train Loss: 0.000919, Val Loss: 0.002859
# Epoch 9, Train Loss: 0.000895, Val Loss: 0.002494
# Epoch 10, Train Loss: 0.000879, Val Loss: 0.002791
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0021952753886580467
# Overall MAE: 0.0346941202878952
# Overall RMSE: 0.046853766002937766
# Success! Clean 2-line graphs saved for LSTM ens160_aqi (len=12)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = ens160_tvoc | Output Length = 1
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.001109, Val Loss: 0.003139
# Epoch 2, Train Loss: 0.000557, Val Loss: 0.002956
# Epoch 3, Train Loss: 0.000510, Val Loss: 0.002402
# Epoch 4, Train Loss: 0.000482, Val Loss: 0.002759
# Epoch 5, Train Loss: 0.000457, Val Loss: 0.003121
# Epoch 6, Train Loss: 0.000438, Val Loss: 0.002953
# Epoch 7, Train Loss: 0.000431, Val Loss: 0.002261
# Epoch 8, Train Loss: 0.000413, Val Loss: 0.002228
# Epoch 9, Train Loss: 0.000402, Val Loss: 0.002274
# Epoch 10, Train Loss: 0.000393, Val Loss: 0.001979
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0018177037127315998
# Overall MAE: 0.0348411425948143
# Overall RMSE: 0.04263453661917296
# Success! Clean 2-line graphs saved for LSTM ens160_tvoc (len=1)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = ens160_tvoc | Output Length = 6
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.001217, Val Loss: 0.001126
# Epoch 2, Train Loss: 0.000655, Val Loss: 0.001133
# Epoch 3, Train Loss: 0.000622, Val Loss: 0.000986
# Epoch 4, Train Loss: 0.000599, Val Loss: 0.000967
# Epoch 5, Train Loss: 0.000577, Val Loss: 0.000897
# Epoch 6, Train Loss: 0.000563, Val Loss: 0.000812
# Epoch 7, Train Loss: 0.000549, Val Loss: 0.000875
# Epoch 8, Train Loss: 0.000543, Val Loss: 0.000776
# Epoch 9, Train Loss: 0.000537, Val Loss: 0.000798
# Epoch 10, Train Loss: 0.000528, Val Loss: 0.000770
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.004790385253727436
# Overall MAE: 0.06198691576719284
# Overall RMSE: 0.06921260906603244
# Success! Clean 2-line graphs saved for LSTM ens160_tvoc (len=6)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = ens160_tvoc | Output Length = 12
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.001573, Val Loss: 0.002099
# Epoch 2, Train Loss: 0.000761, Val Loss: 0.001798
# Epoch 3, Train Loss: 0.000716, Val Loss: 0.001493
# Epoch 4, Train Loss: 0.000701, Val Loss: 0.001446
# Epoch 5, Train Loss: 0.000678, Val Loss: 0.001454
# Epoch 6, Train Loss: 0.000665, Val Loss: 0.001371
# Epoch 7, Train Loss: 0.000650, Val Loss: 0.001466
# Epoch 8, Train Loss: 0.000642, Val Loss: 0.001457
# Epoch 9, Train Loss: 0.000632, Val Loss: 0.001393
# Epoch 10, Train Loss: 0.000629, Val Loss: 0.001362
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0010810201056301594
# Overall MAE: 0.014751467853784561
# Overall RMSE: 0.03287887020002603
# Success! Clean 2-line graphs saved for LSTM ens160_tvoc (len=12)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_temperature | Output Length = 1
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.021538, Val Loss: 0.005389
# Epoch 2, Train Loss: 0.002114, Val Loss: 0.005856
# Epoch 3, Train Loss: 0.001280, Val Loss: 0.006967
# Epoch 4, Train Loss: 0.000933, Val Loss: 0.009696
# Epoch 5, Train Loss: 0.000759, Val Loss: 0.007282
# Epoch 6, Train Loss: 0.000620, Val Loss: 0.009436
# Epoch 7, Train Loss: 0.000527, Val Loss: 0.009902
# Epoch 8, Train Loss: 0.000434, Val Loss: 0.008211
# Epoch 9, Train Loss: 0.000375, Val Loss: 0.009680
# Epoch 10, Train Loss: 0.000320, Val Loss: 0.009154
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.004115259274840355
# Overall MAE: 0.05538521334528923
# Overall RMSE: 0.064150286631007
# Success! Clean 2-line graphs saved for LSTM scd41_temperature (len=1)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_temperature | Output Length = 6
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.036356, Val Loss: 0.006636
# Epoch 2, Train Loss: 0.003498, Val Loss: 0.005221
# Epoch 3, Train Loss: 0.002728, Val Loss: 0.005429
# Epoch 4, Train Loss: 0.002112, Val Loss: 0.004939
# Epoch 5, Train Loss: 0.001697, Val Loss: 0.004867
# Epoch 6, Train Loss: 0.001463, Val Loss: 0.005174
# Epoch 7, Train Loss: 0.001256, Val Loss: 0.007089
# Epoch 8, Train Loss: 0.001146, Val Loss: 0.008443
# Epoch 9, Train Loss: 0.001074, Val Loss: 0.007618
# Epoch 10, Train Loss: 0.001011, Val Loss: 0.007070
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.006581271067261696
# Overall MAE: 0.06771927326917648
# Overall RMSE: 0.08112503354243804
# Success! Clean 2-line graphs saved for LSTM scd41_temperature (len=6)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_temperature | Output Length = 12
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.041316, Val Loss: 0.006557
# Epoch 2, Train Loss: 0.004395, Val Loss: 0.007025
# Epoch 3, Train Loss: 0.003697, Val Loss: 0.008201
# Epoch 4, Train Loss: 0.002927, Val Loss: 0.009156
# Epoch 5, Train Loss: 0.002447, Val Loss: 0.010826
# Epoch 6, Train Loss: 0.002167, Val Loss: 0.010543
# Epoch 7, Train Loss: 0.001938, Val Loss: 0.010132
# Epoch 8, Train Loss: 0.001770, Val Loss: 0.011479
# Epoch 9, Train Loss: 0.001640, Val Loss: 0.009183
# Epoch 10, Train Loss: 0.001553, Val Loss: 0.010152
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.011249997653067112
# Overall MAE: 0.0873556062579155
# Overall RMSE: 0.10606600611443381
# Success! Clean 2-line graphs saved for LSTM scd41_temperature (len=12)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_humidity | Output Length = 1
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.013114, Val Loss: 0.007339
# Epoch 2, Train Loss: 0.001148, Val Loss: 0.007212
# Epoch 3, Train Loss: 0.000819, Val Loss: 0.004843
# Epoch 4, Train Loss: 0.000636, Val Loss: 0.002089
# Epoch 5, Train Loss: 0.000534, Val Loss: 0.001808
# Epoch 6, Train Loss: 0.000458, Val Loss: 0.001944
# Epoch 7, Train Loss: 0.000395, Val Loss: 0.001259
# Epoch 8, Train Loss: 0.000339, Val Loss: 0.001285
# Epoch 9, Train Loss: 0.000303, Val Loss: 0.001313
# Epoch 10, Train Loss: 0.000264, Val Loss: 0.000962
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0049445792101323605
# Overall MAE: 0.06501755863428116
# Overall RMSE: 0.07031770196851117
# Success! Clean 2-line graphs saved for LSTM scd41_humidity (len=1)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_humidity | Output Length = 6
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.022282, Val Loss: 0.012299
# Epoch 2, Train Loss: 0.001972, Val Loss: 0.004809
# Epoch 3, Train Loss: 0.001566, Val Loss: 0.003285
# Epoch 4, Train Loss: 0.001359, Val Loss: 0.001919
# Epoch 5, Train Loss: 0.001221, Val Loss: 0.002250
# Epoch 6, Train Loss: 0.001076, Val Loss: 0.001974
# Epoch 7, Train Loss: 0.000997, Val Loss: 0.002014
# Epoch 8, Train Loss: 0.000920, Val Loss: 0.002347
# Epoch 9, Train Loss: 0.000882, Val Loss: 0.002467
# Epoch 10, Train Loss: 0.000827, Val Loss: 0.002263
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.009054235182702541
# Overall MAE: 0.08664894104003906
# Overall RMSE: 0.09515374497465952
# Success! Clean 2-line graphs saved for LSTM scd41_humidity (len=6)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_humidity | Output Length = 12
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.023155, Val Loss: 0.035927
# Epoch 2, Train Loss: 0.002434, Val Loss: 0.039579
# Epoch 3, Train Loss: 0.002110, Val Loss: 0.036457
# Epoch 4, Train Loss: 0.001903, Val Loss: 0.036667
# Epoch 5, Train Loss: 0.001748, Val Loss: 0.038055
# Epoch 6, Train Loss: 0.001594, Val Loss: 0.032995
# Epoch 7, Train Loss: 0.001508, Val Loss: 0.031085
# Epoch 8, Train Loss: 0.001425, Val Loss: 0.033741
# Epoch 9, Train Loss: 0.001360, Val Loss: 0.027761
# Epoch 10, Train Loss: 0.001290, Val Loss: 0.026789
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.003449820913374424
# Overall MAE: 0.045489951968193054
# Overall RMSE: 0.0587351761159735
# Success! Clean 2-line graphs saved for LSTM scd41_humidity (len=12)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_co2 | Output Length = 1
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
# Epoch 1, Train Loss: 0.004544, Val Loss: 0.005116
# Epoch 2, Train Loss: 0.002160, Val Loss: 0.004525
# Epoch 3, Train Loss: 0.001662, Val Loss: 0.003498
# Epoch 4, Train Loss: 0.001240, Val Loss: 0.001754
# Epoch 5, Train Loss: 0.000900, Val Loss: 0.001080
# Epoch 6, Train Loss: 0.000724, Val Loss: 0.000907
# Epoch 7, Train Loss: 0.000618, Val Loss: 0.000841
# Epoch 8, Train Loss: 0.000563, Val Loss: 0.001014
# Epoch 9, Train Loss: 0.000528, Val Loss: 0.000982
# Epoch 10, Train Loss: 0.000491, Val Loss: 0.000668
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0016585979610681534
# Overall MAE: 0.033633798360824585
# Overall RMSE: 0.040725888094284124
# Success! Clean 2-line graphs saved for LSTM scd41_co2 (len=1)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_co2 | Output Length = 6
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
# Epoch 1, Train Loss: 0.005684, Val Loss: 0.014006
# Epoch 2, Train Loss: 0.003292, Val Loss: 0.011658
# Epoch 3, Train Loss: 0.002916, Val Loss: 0.007663
# Epoch 4, Train Loss: 0.002697, Val Loss: 0.009326
# Epoch 5, Train Loss: 0.002535, Val Loss: 0.007765
# Epoch 6, Train Loss: 0.002419, Val Loss: 0.009422
# Epoch 7, Train Loss: 0.002297, Val Loss: 0.008046
# Epoch 8, Train Loss: 0.002199, Val Loss: 0.006420
# Epoch 9, Train Loss: 0.002119, Val Loss: 0.005233
# Epoch 10, Train Loss: 0.002038, Val Loss: 0.005986
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.001413823920302093
# Overall MAE: 0.02417479269206524
# Overall RMSE: 0.03760084999440961
# Success! Clean 2-line graphs saved for LSTM scd41_co2 (len=6)
#
# ==================================================
# RUNNING LSTM EXPERIMENT: Target = scd41_co2 | Output Length = 12
# ==================================================
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
# Epoch 1, Train Loss: 0.006590, Val Loss: 0.015892
# Epoch 2, Train Loss: 0.003877, Val Loss: 0.018872
# Epoch 3, Train Loss: 0.003587, Val Loss: 0.017293
# Epoch 4, Train Loss: 0.003405, Val Loss: 0.018755
# Epoch 5, Train Loss: 0.003251, Val Loss: 0.016279
# Epoch 6, Train Loss: 0.003144, Val Loss: 0.020101
# Epoch 7, Train Loss: 0.003049, Val Loss: 0.017410
# Epoch 8, Train Loss: 0.002961, Val Loss: 0.016393
# Epoch 9, Train Loss: 0.002889, Val Loss: 0.013199
# Epoch 10, Train Loss: 0.002837, Val Loss: 0.013261
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.006328503135591745
# Overall MAE: 0.06796501576900482
# Overall RMSE: 0.07955188957901468
# Success! Clean 2-line graphs saved for LSTM scd41_co2 (len=12)
#
# DONE! All 15 standard LSTM variants computed successfully. View results folder: 'lstm_experiment_results'
