# %% [markdown]
# # CNN-LSTM Indoor Air Forecasting - Step by Step
#
# This notebook expands the logic from:
#
# - `dataPipeline_CNN_LSTM.py`
# - `src/CNN_LSTM/dataLoad.py`
# - `src/CNN_LSTM/CNN_LSTM.py`
#
# The original pipeline runs everything through one function call. Here, the same important logic is separated into notebook-style steps so you can inspect the data, preprocessing, split, sequences, model, training, evaluation, and plots one by one.

# %% [markdown]
# ## 1. Import Libraries
#
# These imports combine the loading, plotting, preprocessing, PyTorch model, dataloader, scaling, and metric logic from the original files.

# %%
import os
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## 2. Reproducibility and Paths
#
# The script used `data/indoorAir.csv`. In this project folder the available file may be named `indoorAir2.csv`, so this cell checks both names and uses the first one that exists.

# %%
# SEED = 42
# random.seed(SEED)
# np.random.seed(SEED)
# torch.manual_seed(SEED)

PROJECT_DIR = r"C:\Users\Kenil Dhorajiya\Downloads\University\Semester 5\Project\TSA"
DATA_CANDIDATES = [
    os.path.join(PROJECT_DIR, "data", "indoorAir.csv"),
    os.path.join(PROJECT_DIR, "data", "indoorAir2.csv"),
]

CSV_PATH = next((p for p in DATA_CANDIDATES if os.path.exists(p)), None)
if CSV_PATH is None:
    raise FileNotFoundError(f"Could not find any data file from: {DATA_CANDIDATES}")

print(CSV_PATH)
# Out:
# C:\Users\Kenil Dhorajiya\Downloads\University\Semester 5\Project\TSA\data\indoorAir2.csv

# %% [markdown]
# ## 3. Configuration
#
# These constants come from `CNN_LSTM.py`. The target is CO2, and station IDs are used both for splitting and for one-hot station features.

# %%
BASE_FEATURES = [
    "ens160_aqi",
    "ens160_tvoc",
    "bme688_gas_resistance",
    "bme688_pressure",
    "scd41_temperature",
    "scd41_humidity",
    "scd41_co2",
    "hour_sin",
    "hour_cos",
    "dayofweek_sin",
    "dayofweek_cos",
    "is_weekend",
]

PCA_FEATURES = [
    "ens160_aqi",
    "ens160_tvoc",
    "bme688_gas_resistance",
    "bme688_pressure",
    "scd41_temperature",
    "scd41_humidity",
]

TARGET = "scd41_co2"
STATION_COLUMN = "station_id"

INPUT_SEQ_LENGTH = 24   # 24 rows after 15-minute resampling = 6 hours of history
OUTPUT_SEQ_LENGTH = 6   # 6 rows after 15-minute resampling = 1.5 hours forecast horizon
BATCH_SIZE = 32
EPOCHS = 10

# %% [markdown]
# ## 4. Load and Prepare the Raw Dataset
#
# This is the notebook version of `load_prepare_data`. It reads the CSV, converts Unix seconds to timestamps, sorts by time, and makes timestamp the index.

# %%
df = pd.read_csv(CSV_PATH)

print("========== RAW DATASET ==========")
print("Raw dataset shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")
df = df.sort_values(by="timestamp")
df = df.set_index("timestamp")

print("\n========== TIMESTAMP PROCESSING ==========")
print("Dataset shape:", df.shape)
print("\nDate Range:")
print("Start:", df.index.min())
print("End:", df.index.max())

df.head()
# Out:
# ========== RAW DATASET ==========
# Raw dataset shape: (1924653, 21)
#
# Columns:
# ['id', 'station_id', 'station_name', 'timestamp', 'scd41_co2', 'scd41_temperature', 'scd41_humidity', 'ens160_eco2', 'ens160_tvoc', 'ens160_aqi', 'svm41_temperature', 'svm41_humidity', 'svm41_nox_index', 'svm41_voc_index', 'bme688_temperature', 'bme688_humidity', 'bme688_pressure', 'bme688_gas_resistance', 'sfa30_temperature', 'sfa30_humidity', 'sfa30_hco']
#
# ========== TIMESTAMP PROCESSING ==========
# Dataset shape: (1924653, 20)
#
# Date Range:
# Start: 2024-11-13 16:57:56
# End: 2026-04-22 13:10:59
#                      id  station_id      station_name  scd41_co2  \
# timestamp
# 2024-11-13 16:57:56   1           1  station_room_233      488.0
# 2024-11-13 16:58:57   2           1  station_room_233      485.0
# 2024-11-13 16:59:59   3           1  station_room_233      477.0
# 2024-11-13 17:01:03   4           1  station_room_233      474.0
# 2024-11-13 17:02:05   5           1  station_room_233      473.0
#
#                      scd41_temperature  scd41_humidity  ens160_eco2  \
# timestamp
# 2024-11-13 16:57:56          22.951857       36.897277          418
# 2024-11-13 16:58:57          22.335011       38.185119          414
# 2024-11-13 16:59:59          22.353704       38.400268          443
# 2024-11-13 17:01:03          22.417792       38.269042          406
# 2024-11-13 17:02:05          22.556649       37.971496          416
#
#                      ens160_tvoc  ens160_aqi  svm41_temperature  \
# timestamp
# 2024-11-13 16:57:56           32           1          23.684999
# 2024-11-13 16:58:57           30           1          23.590000
# 2024-11-13 16:59:59           43           1          23.655000
# 2024-11-13 17:01:03           26           1          23.709999
# 2024-11-13 17:02:05           31           1          23.659999
#
#                      svm41_humidity  svm41_nox_index  svm41_voc_index  \
# timestamp
# 2024-11-13 16:57:56       34.060001             29.0              1.0
# 2024-11-13 16:58:57       34.209999             79.0              1.0
# 2024-11-13 16:59:59       34.180000             99.0              1.0
# 2024-11-13 17:01:03       34.130001             93.0              1.0
# 2024-11-13 17:02:05       34.240001             98.0              1.0
#
#                      bme688_temperature  bme688_humidity  bme688_pressure  \
# timestamp
# 2024-11-13 16:57:56                 NaN              NaN              NaN
# 2024-11-13 16:58:57                 NaN              NaN              NaN
# 2024-11-13 16:59:59                 NaN              NaN              NaN
# 2024-11-13 17:01:03                 NaN              NaN              NaN
# 2024-11-13 17:02:05                 NaN              NaN              NaN
#
#                      bme688_gas_resistance  sfa30_temperature  sfa30_humidity  \
# timestamp
# 2024-11-13 16:57:56                    NaN                NaN             NaN
# 2024-11-13 16:58:57                    NaN                NaN             NaN
# 2024-11-13 16:59:59                    NaN                NaN             NaN
# 2024-11-13 17:01:03                    NaN                NaN             NaN
# 2024-11-13 17:02:05                    NaN                NaN             NaN
#
#                      sfa30_hco
# timestamp
# 2024-11-13 16:57:56        NaN
# 2024-11-13 16:58:57        NaN
# 2024-11-13 16:59:59        NaN
# 2024-11-13 17:01:03        NaN
# 2024-11-13 17:02:05        NaN

# %% [markdown]
# ## 5. Quick Data Checks
#
# Before modeling, inspect stations, missing values, and numeric summaries. This is useful in a notebook even though the original script mostly prints shapes.

# %%
print("Stations available:", sorted(df[STATION_COLUMN].dropna().unique().tolist()))
print("Total missing values:", df.isna().sum().sum())

df.describe(include="all").T.head(20)
# Out:
# Stations available: [1, 2, 3, 4, 5, 6]
# Total missing values: 8501922
#                            count unique               top    freq  \
# id                     1924653.0    NaN               NaN     NaN
# station_id             1924653.0    NaN               NaN     NaN
# station_name             1924653      6  station_room_233  586547
# scd41_co2              1924653.0    NaN               NaN     NaN
# scd41_temperature      1924653.0    NaN               NaN     NaN
# scd41_humidity         1924653.0    NaN               NaN     NaN
# ens160_eco2            1924653.0    NaN               NaN     NaN
# ens160_tvoc            1924653.0    NaN               NaN     NaN
# ens160_aqi             1924653.0    NaN               NaN     NaN
# svm41_temperature      1155267.0    NaN               NaN     NaN
# svm41_humidity         1155267.0    NaN               NaN     NaN
# svm41_nox_index        1155267.0    NaN               NaN     NaN
# svm41_voc_index        1155267.0    NaN               NaN     NaN
# bme688_temperature     1881393.0    NaN               NaN     NaN
# bme688_humidity        1881393.0    NaN               NaN     NaN
# bme688_pressure        1881393.0    NaN               NaN     NaN
# bme688_gas_resistance  1881393.0    NaN               NaN     NaN
# sfa30_temperature       174207.0    NaN               NaN     NaN
# sfa30_humidity          174207.0    NaN               NaN     NaN
# sfa30_hco               174207.0    NaN               NaN     NaN
#
#                                   mean            std         min         25%  \
# id                       962329.700152  555600.075605         1.0    481167.0
# station_id                    2.847304       1.447816         1.0         1.0
# station_name                       NaN            NaN         NaN         NaN
# scd41_co2                   533.239516     233.990075       365.0       429.0
# scd41_temperature             24.66657       1.750211   15.936903   23.443198
# scd41_humidity               35.090718       8.362188   14.282226   28.643798
# ens160_eco2                 735.495093    3417.101072         0.0       451.0
# ens160_tvoc                 111.988025     354.955305         0.0        47.0
# ens160_aqi                    1.624931         0.7108         0.0         1.0
# svm41_temperature            24.488481       1.842034      -0.005       23.29
# svm41_humidity               35.171222      11.049058 -327.459991        28.6
# svm41_nox_index             111.133658      61.803516        -0.1        75.0
# svm41_voc_index               1.164915       0.517066        -0.1         1.0
# bme688_temperature           26.845749       1.616929       20.03       25.81
# bme688_humidity              26.965543       7.401234       9.198      21.177
# bme688_pressure             100.133822       0.795506       96.22      99.734
# bme688_gas_resistance  12939033.965337   26606.016879  12887828.0  12917167.0
# sfa30_temperature            26.502268       1.321611       24.28       25.67
# sfa30_humidity               28.220087       7.905439   11.319999       21.93
# sfa30_hco                     3.777878       6.298218         0.2         0.6
#
#                               50%         75%         max
# id                       962330.0   1443493.0   1924656.0
# station_id                    3.0         4.0         6.0
# station_name                  NaN         NaN         NaN
# scd41_co2                   457.0       523.0     32774.0
# scd41_temperature        24.51934   25.664911       130.0
# scd41_humidity          33.636474   40.940856   99.998474
# ens160_eco2                 494.0       578.0     65522.0
# ens160_tvoc                  69.0       117.0     65488.0
# ens160_aqi                    2.0         2.0       154.0
# svm41_temperature           24.29   25.344999   41.439998
# svm41_humidity          33.349998   41.409999  325.339996
# svm41_nox_index             101.0       132.0       500.0
# svm41_voc_index               1.0         1.0        25.5
# bme688_temperature          26.73       27.65        44.2
# bme688_humidity            25.772      32.401      68.171
# bme688_pressure            100.22     100.689     102.508
# bme688_gas_resistance  12946860.0  12946860.0  12976914.0
# sfa30_temperature          26.065      26.975   32.459999
# sfa30_humidity          26.719999   34.049999   53.310001
# sfa30_hco                     1.0         3.0   35.400001

# %% [markdown]
# ## 6. Optional EDA: CO2 Time Series
#
# This matches `plot_time_series` from `dataLoad.py`.

# %%
plt.figure(figsize=(10, 4))
plt.plot(df[TARGET])
plt.title("CO2 Time Series")
plt.xlabel("Timestamp")
plt.ylabel("CO2")
plt.show()

# %% [markdown]
# ## 7. Optional EDA: Correlation Heatmap
#
# This matches `plot_heatmap` from `dataLoad.py`.

# %%
corr = df.select_dtypes(include=["float64", "int64"]).corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## 8. Optional EDA: PCA Analysis
#
# This follows `plot_pca_analysis`: select core numerical sensor features, fill missing values with time interpolation plus forward/backward fill, standardize, fit PCA, and plot cumulative explained variance.

# %%
numerical_df = df[PCA_FEATURES].copy()
numerical_df = (
    numerical_df
    .interpolate(method="time")
    .ffill()
    .bfill()
    .dropna()
)

standard_scaler = StandardScaler()
scaled_pca_data = standard_scaler.fit_transform(numerical_df)

pca = PCA()
pca.fit(scaled_pca_data)

explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()

print("========== PCA ANALYSIS ==========")
print("Explained Variance Ratio:")
print(explained_variance)
print("\nCumulative Variance:")
print(cumulative_variance)

plt.figure(figsize=(8, 4))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker="o")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA Cumulative Explained Variance")
plt.grid(True)
plt.show()
# Out:
# ========== PCA ANALYSIS ==========
# Explained Variance Ratio:
# [0.25181935 0.19757189 0.18862874 0.15373756 0.10822613 0.10001632]
#
# Cumulative Variance:
# [0.25181935 0.44939124 0.63801998 0.79175755 0.89998368 1.        ]

# %% [markdown]
# ## 9. Add Time Features
#
# This is the exact feature engineering from `add_time_features`. Hour and day of week are encoded cyclically with sine/cosine, and weekends are marked with a binary flag.

# %%
def add_time_features(input_df):
    output_df = input_df.copy()

    hour = output_df.index.hour
    dayofweek = output_df.index.dayofweek

    output_df["hour_sin"] = np.sin(2 * np.pi * hour / 24)
    output_df["hour_cos"] = np.cos(2 * np.pi * hour / 24)
    output_df["dayofweek_sin"] = np.sin(2 * np.pi * dayofweek / 7)
    output_df["dayofweek_cos"] = np.cos(2 * np.pi * dayofweek / 7)
    output_df["is_weekend"] = (dayofweek >= 5).astype(int)

    return output_df

df_with_time = add_time_features(df)
df_with_time[BASE_FEATURES + [STATION_COLUMN]].head()
# Out:
#                      ens160_aqi  ens160_tvoc  bme688_gas_resistance  \
# timestamp
# 2024-11-13 16:57:56           1           32                    NaN
# 2024-11-13 16:58:57           1           30                    NaN
# 2024-11-13 16:59:59           1           43                    NaN
# 2024-11-13 17:01:03           1           26                    NaN
# 2024-11-13 17:02:05           1           31                    NaN
#
#                      bme688_pressure  scd41_temperature  scd41_humidity  \
# timestamp
# 2024-11-13 16:57:56              NaN          22.951857       36.897277
# 2024-11-13 16:58:57              NaN          22.335011       38.185119
# 2024-11-13 16:59:59              NaN          22.353704       38.400268
# 2024-11-13 17:01:03              NaN          22.417792       38.269042
# 2024-11-13 17:02:05              NaN          22.556649       37.971496
#
#                      scd41_co2  hour_sin  hour_cos  dayofweek_sin  \
# timestamp
# 2024-11-13 16:57:56      488.0 -0.866025 -0.500000       0.974928
# 2024-11-13 16:58:57      485.0 -0.866025 -0.500000       0.974928
# 2024-11-13 16:59:59      477.0 -0.866025 -0.500000       0.974928
# 2024-11-13 17:01:03      474.0 -0.965926 -0.258819       0.974928
# 2024-11-13 17:02:05      473.0 -0.965926 -0.258819       0.974928
#
#                      dayofweek_cos  is_weekend  station_id
# timestamp
# 2024-11-13 16:57:56      -0.222521           0           1
# 2024-11-13 16:58:57      -0.222521           0           1
# 2024-11-13 16:59:59      -0.222521           0           1
# 2024-11-13 17:01:03      -0.222521           0           1
# 2024-11-13 17:02:05      -0.222521           0           1

# %% [markdown]
# ## 10. Select Model Features and Resample by Station
#
# This is the key `preprocess_data` logic. After time features are added, the model keeps only `BASE_FEATURES` and `station_id`, then resamples each station independently to 15-minute intervals using mean values.

# %%
print("========== PREPROCESSING ==========")
print("Raw dataset shape:", df.shape)
print("Stations available:", sorted(df[STATION_COLUMN].unique().tolist()))

model_df = df_with_time[BASE_FEATURES + [STATION_COLUMN]].copy()

print("\nSelected features:")
print(BASE_FEATURES)
print("\nAfter feature selection:", model_df.shape)

model_df = (
    model_df
    .groupby(STATION_COLUMN)
    .resample("15min")
    .mean()
    .drop(columns=STATION_COLUMN, errors="ignore")
    .reset_index(level=0)
)

model_df = model_df[BASE_FEATURES + [STATION_COLUMN]]

print("\nAfter resampling:", model_df.shape)
model_df.head()
# Out:
# ========== PREPROCESSING ==========
# Raw dataset shape: (1924653, 20)
# Stations available: [1, 2, 3, 4, 5, 6]
#
# Selected features:
# ['ens160_aqi', 'ens160_tvoc', 'bme688_gas_resistance', 'bme688_pressure', 'scd41_temperature', 'scd41_humidity', 'scd41_co2', 'hour_sin', 'hour_cos', 'dayofweek_sin', 'dayofweek_cos', 'is_weekend']
#
# After feature selection: (1924653, 13)
#
# After resampling: (186894, 13)
# C:\Users\Kenil Dhorajiya\AppData\Local\Temp\ipykernel_16984\1860017986.py:15: FutureWarning: DataFrameGroupBy.resample operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .mean()
#                      ens160_aqi  ens160_tvoc  bme688_gas_resistance  \
# timestamp
# 2024-11-13 16:45:00         1.0    35.000000                    NaN
# 2024-11-13 17:00:00         1.0    26.857143                    NaN
# 2024-11-13 17:15:00         NaN          NaN                    NaN
# 2024-11-13 17:30:00         NaN          NaN                    NaN
# 2024-11-13 17:45:00         NaN          NaN                    NaN
#
#                      bme688_pressure  scd41_temperature  scd41_humidity  \
# timestamp
# 2024-11-13 16:45:00              NaN          22.546857       37.827555
# 2024-11-13 17:00:00              NaN          22.746242       37.604195
# 2024-11-13 17:15:00              NaN                NaN             NaN
# 2024-11-13 17:30:00              NaN                NaN             NaN
# 2024-11-13 17:45:00              NaN                NaN             NaN
#
#                       scd41_co2  hour_sin  hour_cos  dayofweek_sin  \
# timestamp
# 2024-11-13 16:45:00  483.333333 -0.866025 -0.500000       0.974928
# 2024-11-13 17:00:00  472.285714 -0.965926 -0.258819       0.974928
# 2024-11-13 17:15:00         NaN       NaN       NaN            NaN
# 2024-11-13 17:30:00         NaN       NaN       NaN            NaN
# 2024-11-13 17:45:00         NaN       NaN       NaN            NaN
#
#                      dayofweek_cos  is_weekend  station_id
# timestamp
# 2024-11-13 16:45:00      -0.222521         0.0           1
# 2024-11-13 17:00:00      -0.222521         0.0           1
# 2024-11-13 17:15:00            NaN         NaN           1
# 2024-11-13 17:30:00            NaN         NaN           1
# 2024-11-13 17:45:00            NaN         NaN           1

# %% [markdown]
# ## 11. Cross-Station Train, Validation, and Test Split
#
# The active code uses a cross-station experiment, not a chronological split. It trains on station 3, validates on station 4, and tests on station 5.
#
# The old chronological station-wise split exists only as commented code in the source, so it is kept below as a reference cell and not used for training.

# %%
TRAIN_STATION = 3
VAL_STATION = 4
TEST_STATION = 5

train_df = model_df[model_df[STATION_COLUMN] == TRAIN_STATION].sort_index()
val_df = model_df[model_df[STATION_COLUMN] == VAL_STATION].sort_index()
test_df = model_df[model_df[STATION_COLUMN] == TEST_STATION].sort_index()

print("========== CROSS-STATION SPLIT ==========")
print(f"Training Station: {TRAIN_STATION}")
print("Train shape:", train_df.shape)
print(f"\nValidation Station: {VAL_STATION}")
print("Validation shape:", val_df.shape)
print(f"\nTesting Station: {TEST_STATION}")
print("Test shape:", test_df.shape)

train_parts = [train_df]
val_parts = [val_df]
test_parts = [test_df]
# Out:
# ========== CROSS-STATION SPLIT ==========
# Training Station: 3
# Train shape: (44163, 13)
#
# Validation Station: 4
# Validation shape: (43755, 13)
#
# Testing Station: 5
# Test shape: (29203, 13)

# %% [markdown]
# ### Reference Only: Old Chronological Split
#
# This was commented out in the original file. It is included here so the notebook does not lose that idea, but the active model below uses the cross-station split above.

# %%
# Reference only: not used by the active CNN-LSTM pipeline.
#
# train_parts, val_parts, test_parts = [], [], []
# for station_id, station_df in model_df.groupby(STATION_COLUMN):
#     station_df = station_df.sort_index()
#     train_end = int(len(station_df) * 0.70)
#     val_end = int(len(station_df) * 0.85)
#
#     station_train_df = station_df.iloc[:train_end]
#     station_val_df = station_df.iloc[train_end:val_end]
#     station_test_df = station_df.iloc[val_end:]
#
#     train_parts.append(station_train_df)
#     val_parts.append(station_val_df)
#     test_parts.append(station_test_df)

# %% [markdown]
# ## 12. Fill Missing Values
#
# This follows `fill_missing_parts`. Rows with missing target values are removed first. Other input features are forward-filled and backward-filled inside each split part, and any remaining missing rows are dropped.

# %%
def fill_missing_parts(parts):
    cleaned_parts = []
    input_features = [col for col in BASE_FEATURES if col != TARGET]

    for part in parts:
        part = part.copy()

        print("\nMissing values before interpolation:")
        print(part.isna().sum().sum())

        part = part.dropna(subset=[TARGET])
        part[input_features] = part[input_features].ffill().bfill()
        part = part.dropna()

        print("Missing values after interpolation:")
        print(part.isna().sum().sum())

        if len(part) > 0:
            cleaned_parts.append(part)

    return cleaned_parts

train_parts = fill_missing_parts(train_parts)
val_parts = fill_missing_parts(val_parts)
test_parts = fill_missing_parts(test_parts)

[len(p) for p in train_parts], [len(p) for p in val_parts], [len(p) for p in test_parts]
# Out:
# Missing values before interpolation:
# 226968
# Missing values after interpolation:
# 0
#
# Missing values before interpolation:
# 57672
# Missing values after interpolation:
# 0
#
# Missing values before interpolation:
# 132648
# Missing values after interpolation:
# 0
# ([25249], [38949], [18149])

# %% [markdown]
# ## 13. Add One-Hot Station Features
#
# The original model keeps `station_id` out of the numeric model array and instead creates one-hot station columns for every station found after preprocessing.

# %%
station_ids = sorted(model_df[STATION_COLUMN].unique().tolist())
station_features = [f"station_{sid}" for sid in station_ids]
model_features = BASE_FEATURES + station_features

def build_model_parts(parts, station_ids):
    station_features = [f"station_{sid}" for sid in station_ids]
    model_features = BASE_FEATURES + station_features
    model_parts = []

    for part in parts:
        part = part.copy()

        for sid in station_ids:
            part[f"station_{sid}"] = (part[STATION_COLUMN] == sid).astype(int)

        values = part[model_features].values

        if len(values) > 0:
            model_parts.append(values)

    return model_parts, model_features

train_arrays, model_features = build_model_parts(train_parts, station_ids)
val_arrays, _ = build_model_parts(val_parts, station_ids)
test_arrays, _ = build_model_parts(test_parts, station_ids)

print("Station IDs:", station_ids)
print("Model features:", model_features)
print("Number of model features:", len(model_features))
# Out:
# Station IDs: [1, 2, 3, 4, 5, 6]
# Model features: ['ens160_aqi', 'ens160_tvoc', 'bme688_gas_resistance', 'bme688_pressure', 'scd41_temperature', 'scd41_humidity', 'scd41_co2', 'hour_sin', 'hour_cos', 'dayofweek_sin', 'dayofweek_cos', 'is_weekend', 'station_1', 'station_2', 'station_3', 'station_4', 'station_5', 'station_6']
# Number of model features: 18

# %% [markdown]
# ## 14. Scale Data with Training Data Only
#
# This is an important leakage-prevention step. The `MinMaxScaler` is fit only on the training arrays, then applied to train, validation, and test arrays.

# %%
scaler = MinMaxScaler()
scaler.fit(np.vstack(train_arrays))

print("Scaler fitted ONLY on training data.")

train_scaled = [scaler.transform(p) for p in train_arrays if len(p) > 0]
val_scaled = [scaler.transform(p) for p in val_arrays if len(p) > 0]
test_scaled = [scaler.transform(p) for p in test_arrays if len(p) > 0]

train_scaled[0].shape, val_scaled[0].shape, test_scaled[0].shape
# Out:
# Scaler fitted ONLY on training data.
# ((25249, 18), (38949, 18), (18149, 18))

# %% [markdown]
# ## 15. Create Multi-Step Forecasting Sequences
#
# Each input sample uses `INPUT_SEQ_LENGTH=24` time steps. Each target contains the next `OUTPUT_SEQ_LENGTH=6` CO2 values. The target index is located inside `model_features`, so the target remains correct even after station one-hot features are added.

# %%
def create_sequences(data_parts, model_features, input_seq_length=24, output_seq_length=6):
    X, y = [], []
    target_index = model_features.index(TARGET)

    for data in data_parts:
        print("\nOriginal data shape before sequencing:", data.shape)

        required_length = input_seq_length + output_seq_length

        if len(data) <= required_length:
            print("\nSkipping sequence generation:")
            print(f"Available rows: {len(data)}")
            print(f"Required minimum rows: {required_length + 1}")
            continue

        for i in range(len(data) - input_seq_length - output_seq_length):
            X.append(data[i:i + input_seq_length])
            y.append(data[i + input_seq_length:i + input_seq_length + output_seq_length, target_index])

    X = np.array(X)
    y = np.array(y)

    print("Sequence input shape:", X.shape)
    print("Sequence target shape:", y.shape)

    if len(X) == 0:
        raise ValueError(
            "\nNo CNN-LSTM sequences were created.\n"
            "Possible reasons:\n"
            "- selected station has too few rows\n"
            "- too many missing values removed\n"
            "- input/output sequence lengths are too large\n"
            "- train/validation/test split is too small"
        )

    return X, y

X_train, y_train = create_sequences(train_scaled, model_features, INPUT_SEQ_LENGTH, OUTPUT_SEQ_LENGTH)
X_val, y_val = create_sequences(val_scaled, model_features, INPUT_SEQ_LENGTH, OUTPUT_SEQ_LENGTH)
X_test, y_test = create_sequences(test_scaled, model_features, INPUT_SEQ_LENGTH, OUTPUT_SEQ_LENGTH)
# Out:
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)

# %% [markdown]
# ## 16. Build PyTorch DataLoaders
#
# The training loader shuffles batches. Validation and test loaders keep order stable.

# %%
def create_loader(X, y, batch_size=32, shuffle=False):
    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32)

    loader = DataLoader(
        TensorDataset(X_tensor, y_tensor),
        batch_size=batch_size,
        shuffle=shuffle,
    )

    sample_X, sample_y = next(iter(loader))

    print("\n========== DATALOADER ==========")
    print("Batch input shape:", sample_X.shape)
    print("Batch target shape:", sample_y.shape)

    return loader

train_loader = create_loader(X_train, y_train, BATCH_SIZE, shuffle=True)
val_loader = create_loader(X_val, y_val, BATCH_SIZE, shuffle=False)
test_loader = create_loader(X_test, y_test, BATCH_SIZE, shuffle=False)

input_size = X_train.shape[2]
input_size
# Out:
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
# 18

# %% [markdown]
# ## 17. Define the CNN-LSTM Model
#
# This is the model class from the source file. The input is shaped as `batch, time, features`. The model permutes it for 1D convolutions, applies two convolution layers with ReLU and dropout, permutes back for the LSTM, takes the final LSTM time step, and predicts all future CO2 steps with one linear layer.

# %%
class CNNLSTMModel(nn.Module):
    def __init__(self, input_size, output_seq_length=6, hidden_size=64, num_layers=2, dropout=0.3):
        super().__init__()

        self.conv1 = nn.Conv1d(input_size, 128, kernel_size=5, padding=2)
        self.conv2 = nn.Conv1d(128, 128, kernel_size=3, padding=1)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

        self.lstm = nn.LSTM(
            128,
            hidden_size,
            num_layers,
            batch_first=True,
        )

        self.fc = nn.Linear(hidden_size, output_seq_length)

    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.dropout(self.relu(self.conv1(x)))
        x = self.dropout(self.relu(self.conv2(x)))
        x = x.permute(0, 2, 1)

        output, _ = self.lstm(x)
        output = output[:, -1, :]

        return self.fc(output)

model = CNNLSTMModel(input_size=input_size, output_seq_length=OUTPUT_SEQ_LENGTH)
model
# Out:
# CNNLSTMModel(
#   (conv1): Conv1d(18, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#   (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#   (relu): ReLU()
#   (dropout): Dropout(p=0.3, inplace=False)
#   (lstm): LSTM(128, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=6, bias=True)
# )

# %% [markdown]
# ## 18. Sanity Check One Forward Pass
#
# Before training, check that one batch produces `OUTPUT_SEQ_LENGTH` predictions per sample.

# %%
sample_X, sample_y = next(iter(train_loader))
with torch.no_grad():
    sample_predictions = model(sample_X)

print("Sample input shape:", sample_X.shape)
print("Sample target shape:", sample_y.shape)
print("Sample prediction shape:", sample_predictions.shape)
# Out:
# Sample input shape: torch.Size([32, 24, 18])
# Sample target shape: torch.Size([32, 6])
# Sample prediction shape: torch.Size([32, 6])

# %% [markdown]
# ## 19. Training Helpers
#
# These cells keep the original loss and optimizer choices: MSE loss and Adam with learning rate `0.001`.

# %%
def evaluate_loss(model, loader, criterion):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for X_batch, y_batch in loader:
            predictions = model(X_batch)
            loss = criterion(predictions, y_batch)
            total_loss += loss.item()

    return total_loss / len(loader)


def train_model(model, train_loader, val_loader, epochs=10):
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)

    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        train_loss = 0

        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            predictions = model(X_batch)
            loss = criterion(predictions, y_batch)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        train_loss = train_loss / len(train_loader)
        val_loss = evaluate_loss(model, val_loader, criterion)

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        print(
            f"Epoch {epoch + 1}, "
            f"Train Loss: {train_loss:.6f}, "
            f"Val Loss: {val_loss:.6f}"
        )

    return model, train_losses, val_losses

# %% [markdown]
# ## 20. Train the Model
#
# Run this cell to train the CNN-LSTM. Increase `EPOCHS` in the configuration cell if you want a longer run.

# %%
model, train_losses, val_losses = train_model(
    model,
    train_loader,
    val_loader,
    epochs=EPOCHS,
)
# Out:
# Epoch 1, Train Loss: 0.010579, Val Loss: 0.009126
# Epoch 2, Train Loss: 0.005621, Val Loss: 0.006065
# Epoch 3, Train Loss: 0.003778, Val Loss: 0.005109
# Epoch 4, Train Loss: 0.003449, Val Loss: 0.004567
# Epoch 5, Train Loss: 0.003321, Val Loss: 0.004726
# Epoch 6, Train Loss: 0.003214, Val Loss: 0.004498
# Epoch 7, Train Loss: 0.003128, Val Loss: 0.004722
# Epoch 8, Train Loss: 0.003041, Val Loss: 0.004715
# Epoch 9, Train Loss: 0.002998, Val Loss: 0.005025
# Epoch 10, Train Loss: 0.002953, Val Loss: 0.004683

# %% [markdown]
# ## 21. Plot Training and Validation Loss
#
# This is the notebook version of `plot_loss_curves`.

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# # 22. Evaluate on the Test Station
#
# This follows `evaluate_model`. The metrics are computed after flattening all forecast steps together, exactly like the source code.

# %%
def evaluate_model(model, test_loader):
    model.eval()
    predictions = []
    actuals = []

    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            outputs = model(X_batch)
            predictions.extend(outputs.numpy())
            actuals.extend(y_batch.numpy())

    predictions = np.array(predictions)
    actuals = np.array(actuals)

    mse = mean_squared_error(actuals.flatten(), predictions.flatten())
    mae = mean_absolute_error(actuals.flatten(), predictions.flatten())
    rmse = np.sqrt(mse)

    print("\n========== MODEL EVALUATION ==========")
    print("Overall MSE:", mse)
    print("Overall MAE:", mae)
    print("Overall RMSE:", rmse)

    return predictions, actuals, mse, mae, rmse

predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)
# Out:
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.005719379521906376
# Overall MAE: 0.06614290177822113
# Overall RMSE: 0.07562657946718453

# %% [markdown]
# ## 23. Optional Per-Step Forecast Metrics
#
# The per-step metric block was commented out in the source. It is useful in a notebook because this is a multi-step forecast, so each forecast horizon can behave differently.

# %%
for step in range(actuals.shape[1]):
    step_mse = mean_squared_error(actuals[:, step], predictions[:, step])
    step_mae = mean_absolute_error(actuals[:, step], predictions[:, step])
    step_rmse = np.sqrt(step_mse)

    print(f"Forecast Step {step + 1}")
    print(f"MSE: {step_mse:.6f}")
    print(f"MAE: {step_mae:.6f}")
    print(f"RMSE: {step_rmse:.6f}\n")
# Out:
# Forecast Step 1
# MSE: 0.005913
# MAE: 0.069030
# RMSE: 0.076893
#
# Forecast Step 2
# MSE: 0.007169
# MAE: 0.077131
# RMSE: 0.084667
#
# Forecast Step 3
# MSE: 0.004442
# MAE: 0.056147
# RMSE: 0.066650
#
# Forecast Step 4
# MSE: 0.006941
# MAE: 0.075480
# RMSE: 0.083314
#
# Forecast Step 5
# MSE: 0.004690
# MAE: 0.057802
# RMSE: 0.068480
#
# Forecast Step 6
# MSE: 0.005162
# MAE: 0.061266
# RMSE: 0.071848

# %% [markdown]
# ## 24. Plot Actual vs Predicted CO2
#
# This matches `plot_predictions`. Change `FORECAST_STEP_TO_PLOT` from 1 to 6 to inspect different forecast horizons.

# %%
FORECAST_STEP_TO_PLOT = 1
step_index = FORECAST_STEP_TO_PLOT - 1

plt.figure(figsize=(10, 4))
plt.plot(actuals[:, step_index], label="Actual")
plt.plot(predictions[:, step_index], label="Predicted")
plt.legend()
plt.title(f"Actual vs Predicted CO2 for CNN-LSTM (Forecast Step {FORECAST_STEP_TO_PLOT})")
plt.xlabel("Test sequence")
plt.ylabel("Scaled CO2")
plt.show()

# %% [markdown]
# ## 25. Collect Results
#
# This mirrors the dictionary returned by `run_cnn_lstm_model`.

# %%
cnn_results = {
    "model": model,
    "predictions": predictions,
    "actuals": actuals,
    "mse": mse,
    "mae": mae,
    "rmse": rmse,
}

cnn_results.keys()
# Out:
# dict_keys(['model', 'predictions', 'actuals', 'mse', 'mae', 'rmse'])

# %% [markdown]
# ## 26. Optional: Save the Trained Model
#
# The original script returns the model but does not save it. This optional cell saves the trained PyTorch weights if you want to reuse them later.

# %%
# Optional save. Uncomment when needed.
# MODEL_OUTPUT_PATH = os.path.join(PROJECT_DIR, "notebooks", "cnn_lstm_model.pt")
# torch.save(model.state_dict(), MODEL_OUTPUT_PATH)
# MODEL_OUTPUT_PATH

# %% [markdown]
# ## 27. Compact Function Version
#
# After running the notebook step by step, this helper gives you a compact function similar to the original `run_pipeline`, while still using the notebook-defined pieces above.

# %%
def run_notebook_pipeline(raw_df, epochs=10, input_seq_length=24, output_seq_length=6, batch_size=32):
    prepared = add_time_features(raw_df)
    prepared = prepared[BASE_FEATURES + [STATION_COLUMN]]
    prepared = (
        prepared
        .groupby(STATION_COLUMN)
        .resample("15min")
        .mean()
        .drop(columns=STATION_COLUMN, errors="ignore")
        .reset_index(level=0)
    )
    prepared = prepared[BASE_FEATURES + [STATION_COLUMN]]

    station_ids = sorted(prepared[STATION_COLUMN].unique().tolist())

    train_parts = [prepared[prepared[STATION_COLUMN] == TRAIN_STATION].sort_index()]
    val_parts = [prepared[prepared[STATION_COLUMN] == VAL_STATION].sort_index()]
    test_parts = [prepared[prepared[STATION_COLUMN] == TEST_STATION].sort_index()]

    train_parts = fill_missing_parts(train_parts)
    val_parts = fill_missing_parts(val_parts)
    test_parts = fill_missing_parts(test_parts)

    train_arrays, model_features = build_model_parts(train_parts, station_ids)
    val_arrays, _ = build_model_parts(val_parts, station_ids)
    test_arrays, _ = build_model_parts(test_parts, station_ids)

    scaler = MinMaxScaler()
    scaler.fit(np.vstack(train_arrays))

    train_scaled = [scaler.transform(p) for p in train_arrays if len(p) > 0]
    val_scaled = [scaler.transform(p) for p in val_arrays if len(p) > 0]
    test_scaled = [scaler.transform(p) for p in test_arrays if len(p) > 0]

    X_train, y_train = create_sequences(train_scaled, model_features, input_seq_length, output_seq_length)
    X_val, y_val = create_sequences(val_scaled, model_features, input_seq_length, output_seq_length)
    X_test, y_test = create_sequences(test_scaled, model_features, input_seq_length, output_seq_length)

    train_loader = create_loader(X_train, y_train, batch_size, shuffle=True)
    val_loader = create_loader(X_val, y_val, batch_size, shuffle=False)
    test_loader = create_loader(X_test, y_test, batch_size, shuffle=False)

    model = CNNLSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
    model, train_losses, val_losses = train_model(model, train_loader, val_loader, epochs=epochs)
    predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)

    return {
        "model": model,
        "predictions": predictions,
        "actuals": actuals,
        "mse": mse,
        "mae": mae,
        "rmse": rmse,
        "train_losses": train_losses,
        "val_losses": val_losses,
    }

# %% [markdown]
# ## 28. This Code Below Is Show The All Results Here

# %% [markdown]
# ## 28. This Code Below Is Show The All Results Here

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Force Jupyter to display matplotlib plots directly inside the notebook inline
# %matplotlib inline

global TARGET, model_features

# ==========================================
# 1. PIPELINE FUNCTION WRAPPER
# ==========================================
def run_pipeline(target_feature, output_seq_length, epochs=10):
    global TARGET, model_features
    TARGET = target_feature 
    input_seq_length = 24  
    batch_size = 32
    
    X_train, y_train = create_sequences(train_scaled, model_features, input_seq_length, output_seq_length)
    X_val, y_val = create_sequences(val_scaled, model_features, input_seq_length, output_seq_length)
    X_test, y_test = create_sequences(test_scaled, model_features, input_seq_length, output_seq_length)
    
    train_loader = create_loader(X_train, y_train, batch_size, shuffle=True)
    val_loader = create_loader(X_val, y_val, batch_size, shuffle=False)
    test_loader = create_loader(X_test, y_test, batch_size, shuffle=False)
    
    # Dynamically switches based on whether you are running the LSTM or CNNLSTM notebook
    if 'CNNLSTMModel' in globals():
        model = CNNLSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
    else:
        model = LSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
        
    model, train_losses, val_losses = train_model(model, train_loader, val_loader, epochs=epochs)
    predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)
    
    return {
        "predictions": predictions,
        "actuals": actuals,
        "train_losses": train_losses,
        "val_losses": val_losses
    }

# ==========================================
# 2. MASTER EXPERIMENT LOOP WITH SUBPLOT GRID
# ==========================================
output_lengths = [1, 6, 12, 24, 48]
target_features = [
    "ens160_aqi", 
    "ens160_tvoc", 
    "scd41_temperature", 
    "scd41_humidity", 
    "scd41_co2"
]

# Define a list to collect plotting data so we can display 4 charts per row smoothly
plot_queue = []

print("Starting automation run... Processing variants...")

for target in target_features:
    for out_len in output_lengths:
        print(f"Processing: Target = {target} | Length = {out_len}")
        try:
            results = run_pipeline(
                target_feature=target, 
                output_seq_length=out_len,
                epochs=10
            )
            
            # Extract target lines for predictions
            if out_len > 1:
                plot_actuals = results["actuals"][:200, 0]
                plot_preds = results["predictions"][:200, 0]
            else:
                plot_actuals = results["actuals"][:200].flatten()
                plot_preds = results["predictions"][:200].flatten()
            
            # Queue data for the display grid
            plot_queue.append({
                "type": "loss",
                "title": f"Loss: {target} (Len: {out_len})",
                "data1": results["train_losses"],
                "data2": results["val_losses"],
                "label1": "Train Loss",
                "label2": "Val Loss"
            })
            
            plot_queue.append({
                "type": "pred",
                "title": f"Pred: {target} (Len: {out_len})",
                "data1": plot_actuals,
                "data2": plot_preds,
                "label1": "Actual",
                "label2": "Predicted"
            })
            
        except Exception as e:
            print(f" Error during variant [{target} | Length {out_len}]: {e}")

# ==========================================
# 3. RENDER THE RESULTS DIRECTLY IN JUPYTER (4 PER ROW)
# ==========================================
print("\n" + "="*60)
print("Rendering Visual Grid Directly Inside Jupyter Notebook Below:")
print("="*60 + "\n")

plots_per_row = 4
total_plots = len(plot_queue)

# Loop over the items jumping 4 at a time to build clean horizontal rows
for i in range(0, total_plots, plots_per_row):
    current_chunk = plot_queue[i : i + plots_per_row]
    num_cols = len(current_chunk)
    
    # Create an explicit wide row layout (width: 24 inches, height: 5 inches)
    fig, axes = plt.subplots(1, plots_per_row, figsize=(24, 5))
    
    # Handle indexing fallback if only 1 plot is left near the very end
    if plots_per_row == 1:
        axes = [axes]
        
    for col_idx in range(plots_per_row):
        ax = axes[col_idx]
        
        if col_idx < num_cols:
            item = current_chunk[col_idx]
            
            # Plot the specific lines assigned to this column quadrant
            ax.plot(item["data1"], label=item["label1"], color="blue", alpha=0.7)
            ax.plot(item["data2"], label=item["label2"], color="orange", alpha=0.8)
            ax.set_title(item["title"], fontsize=11, fontweight="bold")
            ax.legend(loc="upper right")
            ax.grid(True, linestyle="--", alpha=0.5)
            
            # Add structural labels depending on graph context
            if item["type"] == "loss":
                ax.set_xlabel("Epochs")
                ax.set_ylabel("Loss Value")
            else:
                ax.set_xlabel("Time Steps")
                ax.set_ylabel("Scaled Value")
        else:
            # Hide empty remaining placeholders if the total number of items isn't divisible by 4
            ax.axis('off')
            
    plt.tight_layout()
    plt.show() # Forces immediate output display down below the current notebook cell

print("\n ALL EXPERIMENTS FINISHED! Everything displayed above.")
# Out:
# Starting automation run... Processing variants...
# Processing: Target = ens160_aqi | Length = 1
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
# Epoch 1, Train Loss: 0.013227, Val Loss: 0.004639
# Epoch 2, Train Loss: 0.002751, Val Loss: 0.003885
# Epoch 3, Train Loss: 0.001801, Val Loss: 0.001730
# Epoch 4, Train Loss: 0.001249, Val Loss: 0.001406
# Epoch 5, Train Loss: 0.001068, Val Loss: 0.001278
# Epoch 6, Train Loss: 0.000953, Val Loss: 0.001460
# Epoch 7, Train Loss: 0.000866, Val Loss: 0.001167
# Epoch 8, Train Loss: 0.000825, Val Loss: 0.001335
# Epoch 9, Train Loss: 0.000780, Val Loss: 0.001182
# Epoch 10, Train Loss: 0.000749, Val Loss: 0.001189
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0031035402789711952
# Overall MAE: 0.045566629618406296
# Overall RMSE: 0.055709427200171385
# Processing: Target = ens160_aqi | Length = 6
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
# Epoch 1, Train Loss: 0.008789, Val Loss: 0.004147
# Epoch 2, Train Loss: 0.002985, Val Loss: 0.006075
# Epoch 3, Train Loss: 0.001786, Val Loss: 0.004423
# Epoch 4, Train Loss: 0.001408, Val Loss: 0.004469
# Epoch 5, Train Loss: 0.001269, Val Loss: 0.002688
# Epoch 6, Train Loss: 0.001191, Val Loss: 0.002044
# Epoch 7, Train Loss: 0.001122, Val Loss: 0.002100
# Epoch 8, Train Loss: 0.001081, Val Loss: 0.001782
# Epoch 9, Train Loss: 0.001033, Val Loss: 0.001591
# Epoch 10, Train Loss: 0.001001, Val Loss: 0.001341
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.008311874233186245
# Overall MAE: 0.08172839134931564
# Overall RMSE: 0.09116948082108532
# Processing: Target = ens160_aqi | Length = 12
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
# Epoch 1, Train Loss: 0.013740, Val Loss: 0.003409
# Epoch 2, Train Loss: 0.003433, Val Loss: 0.003456
# Epoch 3, Train Loss: 0.002573, Val Loss: 0.004048
# Epoch 4, Train Loss: 0.001824, Val Loss: 0.005627
# Epoch 5, Train Loss: 0.001554, Val Loss: 0.005483
# Epoch 6, Train Loss: 0.001418, Val Loss: 0.006219
# Epoch 7, Train Loss: 0.001330, Val Loss: 0.006026
# Epoch 8, Train Loss: 0.001265, Val Loss: 0.006099
# Epoch 9, Train Loss: 0.001216, Val Loss: 0.006263
# Epoch 10, Train Loss: 0.001185, Val Loss: 0.005992
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.019348451867699623
# Overall MAE: 0.13237108290195465
# Overall RMSE: 0.13909871267448748
# Processing: Target = ens160_aqi | Length = 24
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
# Epoch 1, Train Loss: 0.011603, Val Loss: 0.003347
# Epoch 2, Train Loss: 0.003320, Val Loss: 0.003185
# Epoch 3, Train Loss: 0.002595, Val Loss: 0.002716
# Epoch 4, Train Loss: 0.001980, Val Loss: 0.002739
# Epoch 5, Train Loss: 0.001782, Val Loss: 0.002620
# Epoch 6, Train Loss: 0.001678, Val Loss: 0.002453
# Epoch 7, Train Loss: 0.001616, Val Loss: 0.002482
# Epoch 8, Train Loss: 0.001562, Val Loss: 0.002709
# Epoch 9, Train Loss: 0.001518, Val Loss: 0.002780
# Epoch 10, Train Loss: 0.001493, Val Loss: 0.003046
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0032725126948207617
# Overall MAE: 0.04396185278892517
# Overall RMSE: 0.05720587989726897
# Processing: Target = ens160_aqi | Length = 48
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
# Epoch 1, Train Loss: 0.012826, Val Loss: 0.003676
# Epoch 2, Train Loss: 0.003627, Val Loss: 0.003550
# Epoch 3, Train Loss: 0.003209, Val Loss: 0.005290
# Epoch 4, Train Loss: 0.002659, Val Loss: 0.008260
# Epoch 5, Train Loss: 0.002312, Val Loss: 0.009385
# Epoch 6, Train Loss: 0.002192, Val Loss: 0.008716
# Epoch 7, Train Loss: 0.002105, Val Loss: 0.009356
# Epoch 8, Train Loss: 0.002037, Val Loss: 0.009269
# Epoch 9, Train Loss: 0.001997, Val Loss: 0.009792
# Epoch 10, Train Loss: 0.001949, Val Loss: 0.011221
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.005830995738506317
# Overall MAE: 0.06505591422319412
# Overall RMSE: 0.0763609568988388
# Processing: Target = ens160_tvoc | Length = 1
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
# Epoch 1, Train Loss: 0.001552, Val Loss: 0.001852
# Epoch 2, Train Loss: 0.001365, Val Loss: 0.001734
# Epoch 3, Train Loss: 0.001140, Val Loss: 0.001526
# Epoch 4, Train Loss: 0.000909, Val Loss: 0.001306
# Epoch 5, Train Loss: 0.000682, Val Loss: 0.001038
# Epoch 6, Train Loss: 0.000570, Val Loss: 0.001011
# Epoch 7, Train Loss: 0.000545, Val Loss: 0.000947
# Epoch 8, Train Loss: 0.000539, Val Loss: 0.000872
# Epoch 9, Train Loss: 0.000526, Val Loss: 0.000879
# Epoch 10, Train Loss: 0.000521, Val Loss: 0.000835
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.00490125035867095
# Overall MAE: 0.06137823686003685
# Overall RMSE: 0.07000893056368558
# Processing: Target = ens160_tvoc | Length = 6
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
# Epoch 1, Train Loss: 0.003633, Val Loss: 0.002017
# Epoch 2, Train Loss: 0.001512, Val Loss: 0.001949
# Epoch 3, Train Loss: 0.001404, Val Loss: 0.002064
# Epoch 4, Train Loss: 0.001229, Val Loss: 0.002156
# Epoch 5, Train Loss: 0.001002, Val Loss: 0.002232
# Epoch 6, Train Loss: 0.000792, Val Loss: 0.001964
# Epoch 7, Train Loss: 0.000694, Val Loss: 0.001583
# Epoch 8, Train Loss: 0.000659, Val Loss: 0.001561
# Epoch 9, Train Loss: 0.000639, Val Loss: 0.001458
# Epoch 10, Train Loss: 0.000626, Val Loss: 0.001491
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0010928316041827202
# Overall MAE: 0.013946657069027424
# Overall RMSE: 0.03305800363274709
# Processing: Target = ens160_tvoc | Length = 12
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
# Epoch 1, Train Loss: 0.003153, Val Loss: 0.002006
# Epoch 2, Train Loss: 0.001496, Val Loss: 0.002018
# Epoch 3, Train Loss: 0.001407, Val Loss: 0.002039
# Epoch 4, Train Loss: 0.001278, Val Loss: 0.002217
# Epoch 5, Train Loss: 0.001111, Val Loss: 0.001997
# Epoch 6, Train Loss: 0.000915, Val Loss: 0.001894
# Epoch 7, Train Loss: 0.000798, Val Loss: 0.001783
# Epoch 8, Train Loss: 0.000754, Val Loss: 0.001723
# Epoch 9, Train Loss: 0.000732, Val Loss: 0.001565
# Epoch 10, Train Loss: 0.000719, Val Loss: 0.001571
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0024357615038752556
# Overall MAE: 0.038208261132240295
# Overall RMSE: 0.04935343457020246
# Processing: Target = ens160_tvoc | Length = 24
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
# Epoch 1, Train Loss: 0.003952, Val Loss: 0.001834
# Epoch 2, Train Loss: 0.001546, Val Loss: 0.001686
# Epoch 3, Train Loss: 0.001485, Val Loss: 0.001703
# Epoch 4, Train Loss: 0.001419, Val Loss: 0.001679
# Epoch 5, Train Loss: 0.001319, Val Loss: 0.001667
# Epoch 6, Train Loss: 0.001180, Val Loss: 0.001569
# Epoch 7, Train Loss: 0.001020, Val Loss: 0.001273
# Epoch 8, Train Loss: 0.000902, Val Loss: 0.001046
# Epoch 9, Train Loss: 0.000855, Val Loss: 0.000983
# Epoch 10, Train Loss: 0.000827, Val Loss: 0.001031
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.002398543991148472
# Overall MAE: 0.03325379267334938
# Overall RMSE: 0.048974932273036086
# Processing: Target = ens160_tvoc | Length = 48
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
# Epoch 1, Train Loss: 0.004122, Val Loss: 0.001139
# Epoch 2, Train Loss: 0.001567, Val Loss: 0.001036
# Epoch 3, Train Loss: 0.001520, Val Loss: 0.001009
# Epoch 4, Train Loss: 0.001477, Val Loss: 0.000974
# Epoch 5, Train Loss: 0.001423, Val Loss: 0.000950
# Epoch 6, Train Loss: 0.001351, Val Loss: 0.000893
# Epoch 7, Train Loss: 0.001273, Val Loss: 0.000850
# Epoch 8, Train Loss: 0.001185, Val Loss: 0.000819
# Epoch 9, Train Loss: 0.001103, Val Loss: 0.000799
# Epoch 10, Train Loss: 0.001048, Val Loss: 0.000764
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0018305426929146051
# Overall MAE: 0.011313477531075478
# Overall RMSE: 0.0427848418591749
# Processing: Target = scd41_temperature | Length = 1
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
# Epoch 1, Train Loss: 0.156101, Val Loss: 0.071578
# Epoch 2, Train Loss: 0.016442, Val Loss: 0.056009
# Epoch 3, Train Loss: 0.007719, Val Loss: 0.039723
# Epoch 4, Train Loss: 0.004026, Val Loss: 0.024482
# Epoch 5, Train Loss: 0.002994, Val Loss: 0.018728
# Epoch 6, Train Loss: 0.002556, Val Loss: 0.014348
# Epoch 7, Train Loss: 0.002316, Val Loss: 0.014716
# Epoch 8, Train Loss: 0.002178, Val Loss: 0.015007
# Epoch 9, Train Loss: 0.002048, Val Loss: 0.013396
# Epoch 10, Train Loss: 0.001942, Val Loss: 0.013721
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.026663117110729218
# Overall MAE: 0.1436423808336258
# Overall RMSE: 0.16328844757278213
# Processing: Target = scd41_temperature | Length = 6
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
# Epoch 1, Train Loss: 0.169740, Val Loss: 0.059755
# Epoch 2, Train Loss: 0.016783, Val Loss: 0.070988
# Epoch 3, Train Loss: 0.008731, Val Loss: 0.150482
# Epoch 4, Train Loss: 0.004791, Val Loss: 0.192374
# Epoch 5, Train Loss: 0.003870, Val Loss: 0.196098
# Epoch 6, Train Loss: 0.003451, Val Loss: 0.205976
# Epoch 7, Train Loss: 0.003171, Val Loss: 0.211344
# Epoch 8, Train Loss: 0.002970, Val Loss: 0.196958
# Epoch 9, Train Loss: 0.002795, Val Loss: 0.204236
# Epoch 10, Train Loss: 0.002669, Val Loss: 0.196053
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.09136340022087097
# Overall MAE: 0.29096126556396484
# Overall RMSE: 0.30226379244109103
# Processing: Target = scd41_temperature | Length = 12
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
# Epoch 1, Train Loss: 0.178457, Val Loss: 0.048381
# Epoch 2, Train Loss: 0.017250, Val Loss: 0.054575
# Epoch 3, Train Loss: 0.010466, Val Loss: 0.035265
# Epoch 4, Train Loss: 0.005908, Val Loss: 0.021413
# Epoch 5, Train Loss: 0.004769, Val Loss: 0.020368
# Epoch 6, Train Loss: 0.004291, Val Loss: 0.021375
# Epoch 7, Train Loss: 0.003879, Val Loss: 0.016507
# Epoch 8, Train Loss: 0.003577, Val Loss: 0.017092
# Epoch 9, Train Loss: 0.003347, Val Loss: 0.017384
# Epoch 10, Train Loss: 0.003138, Val Loss: 0.015617
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.01645006239414215
# Overall MAE: 0.1080174371600151
# Overall RMSE: 0.12825779662126646
# Processing: Target = scd41_temperature | Length = 24
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
# Epoch 1, Train Loss: 0.195450, Val Loss: 0.043535
# Epoch 2, Train Loss: 0.018955, Val Loss: 0.048915
# Epoch 3, Train Loss: 0.015203, Val Loss: 0.037161
# Epoch 4, Train Loss: 0.008823, Val Loss: 0.027592
# Epoch 5, Train Loss: 0.006669, Val Loss: 0.022670
# Epoch 6, Train Loss: 0.005879, Val Loss: 0.020482
# Epoch 7, Train Loss: 0.005346, Val Loss: 0.017950
# Epoch 8, Train Loss: 0.004987, Val Loss: 0.017539
# Epoch 9, Train Loss: 0.004659, Val Loss: 0.015976
# Epoch 10, Train Loss: 0.004413, Val Loss: 0.016604
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.01066700741648674
# Overall MAE: 0.07506150007247925
# Overall RMSE: 0.103281205533663
# Processing: Target = scd41_temperature | Length = 48
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
# Epoch 1, Train Loss: 0.207076, Val Loss: 0.043805
# Epoch 2, Train Loss: 0.022612, Val Loss: 0.050693
# Epoch 3, Train Loss: 0.016518, Val Loss: 0.054145
# Epoch 4, Train Loss: 0.010763, Val Loss: 0.060250
# Epoch 5, Train Loss: 0.008038, Val Loss: 0.056289
# Epoch 6, Train Loss: 0.007113, Val Loss: 0.053470
# Epoch 7, Train Loss: 0.006558, Val Loss: 0.047032
# Epoch 8, Train Loss: 0.006132, Val Loss: 0.047212
# Epoch 9, Train Loss: 0.005712, Val Loss: 0.041237
# Epoch 10, Train Loss: 0.005321, Val Loss: 0.040981
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.019163139164447784
# Overall MAE: 0.11389219760894775
# Overall RMSE: 0.13843099062149264
# Processing: Target = scd41_humidity | Length = 1
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
# Epoch 1, Train Loss: 0.079572, Val Loss: 0.028913
# Epoch 2, Train Loss: 0.010627, Val Loss: 0.008907
# Epoch 3, Train Loss: 0.002768, Val Loss: 0.014757
# Epoch 4, Train Loss: 0.001953, Val Loss: 0.015606
# Epoch 5, Train Loss: 0.001689, Val Loss: 0.014557
# Epoch 6, Train Loss: 0.001545, Val Loss: 0.014886
# Epoch 7, Train Loss: 0.001458, Val Loss: 0.013767
# Epoch 8, Train Loss: 0.001385, Val Loss: 0.012949
# Epoch 9, Train Loss: 0.001305, Val Loss: 0.011553
# Epoch 10, Train Loss: 0.001269, Val Loss: 0.012142
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.018085794523358345
# Overall MAE: 0.11727699637413025
# Overall RMSE: 0.13448343586984363
# Processing: Target = scd41_humidity | Length = 6
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
# Epoch 1, Train Loss: 0.061567, Val Loss: 0.036156
# Epoch 2, Train Loss: 0.013550, Val Loss: 0.036989
# Epoch 3, Train Loss: 0.003350, Val Loss: 0.030322
# Epoch 4, Train Loss: 0.002582, Val Loss: 0.023990
# Epoch 5, Train Loss: 0.002330, Val Loss: 0.023881
# Epoch 6, Train Loss: 0.002161, Val Loss: 0.022678
# Epoch 7, Train Loss: 0.002024, Val Loss: 0.021541
# Epoch 8, Train Loss: 0.001922, Val Loss: 0.020481
# Epoch 9, Train Loss: 0.001835, Val Loss: 0.023287
# Epoch 10, Train Loss: 0.001748, Val Loss: 0.021424
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.006964921951293945
# Overall MAE: 0.06686647981405258
# Overall RMSE: 0.08345610793281667
# Processing: Target = scd41_humidity | Length = 12
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
# Epoch 1, Train Loss: 0.092068, Val Loss: 0.035103
# Epoch 2, Train Loss: 0.016529, Val Loss: 0.013027
# Epoch 3, Train Loss: 0.004147, Val Loss: 0.016282
# Epoch 4, Train Loss: 0.002992, Val Loss: 0.016306
# Epoch 5, Train Loss: 0.002638, Val Loss: 0.014752
# Epoch 6, Train Loss: 0.002414, Val Loss: 0.014044
# Epoch 7, Train Loss: 0.002282, Val Loss: 0.012419
# Epoch 8, Train Loss: 0.002182, Val Loss: 0.010705
# Epoch 9, Train Loss: 0.002110, Val Loss: 0.010708
# Epoch 10, Train Loss: 0.002038, Val Loss: 0.010085
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.012372585944831371
# Overall MAE: 0.09597122669219971
# Overall RMSE: 0.11123212640613939
# Processing: Target = scd41_humidity | Length = 24
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
# Epoch 1, Train Loss: 0.096640, Val Loss: 0.041366
# Epoch 2, Train Loss: 0.023318, Val Loss: 0.032207
# Epoch 3, Train Loss: 0.007620, Val Loss: 0.006649
# Epoch 4, Train Loss: 0.003795, Val Loss: 0.005405
# Epoch 5, Train Loss: 0.003372, Val Loss: 0.004768
# Epoch 6, Train Loss: 0.003111, Val Loss: 0.004443
# Epoch 7, Train Loss: 0.002948, Val Loss: 0.004084
# Epoch 8, Train Loss: 0.002838, Val Loss: 0.004274
# Epoch 9, Train Loss: 0.002735, Val Loss: 0.004247
# Epoch 10, Train Loss: 0.002655, Val Loss: 0.004168
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.009667731821537018
# Overall MAE: 0.07861753553152084
# Overall RMSE: 0.09832462469563268
# Processing: Target = scd41_humidity | Length = 48
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
# Epoch 1, Train Loss: 0.093140, Val Loss: 0.045020
# Epoch 2, Train Loss: 0.019961, Val Loss: 0.021712
# Epoch 3, Train Loss: 0.006424, Val Loss: 0.009781
# Epoch 4, Train Loss: 0.004885, Val Loss: 0.008882
# Epoch 5, Train Loss: 0.004382, Val Loss: 0.008557
# Epoch 6, Train Loss: 0.004111, Val Loss: 0.009039
# Epoch 7, Train Loss: 0.003923, Val Loss: 0.008548
# Epoch 8, Train Loss: 0.003808, Val Loss: 0.008939
# Epoch 9, Train Loss: 0.003688, Val Loss: 0.009285
# Epoch 10, Train Loss: 0.003600, Val Loss: 0.009506
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.008784573525190353
# Overall MAE: 0.07353024184703827
# Overall RMSE: 0.09372605574326892
# Processing: Target = scd41_co2 | Length = 1
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25224, 24, 18)
# Sequence target shape: (25224, 1)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38924, 24, 18)
# Sequence target shape: (38924, 1)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18124, 24, 18)
# Sequence target shape: (18124, 1)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 1])
# Epoch 1, Train Loss: 0.009628, Val Loss: 0.009380
# Epoch 2, Train Loss: 0.004982, Val Loss: 0.005364
# Epoch 3, Train Loss: 0.002775, Val Loss: 0.003737
# Epoch 4, Train Loss: 0.002537, Val Loss: 0.003435
# Epoch 5, Train Loss: 0.002337, Val Loss: 0.003328
# Epoch 6, Train Loss: 0.002212, Val Loss: 0.003450
# Epoch 7, Train Loss: 0.002144, Val Loss: 0.003295
# Epoch 8, Train Loss: 0.002090, Val Loss: 0.003526
# Epoch 9, Train Loss: 0.002001, Val Loss: 0.003287
# Epoch 10, Train Loss: 0.001899, Val Loss: 0.003244
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0027688464615494013
# Overall MAE: 0.04299274832010269
# Overall RMSE: 0.05261982954694362
# Processing: Target = scd41_co2 | Length = 6
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25219, 24, 18)
# Sequence target shape: (25219, 6)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38919, 24, 18)
# Sequence target shape: (38919, 6)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18119, 24, 18)
# Sequence target shape: (18119, 6)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 6])
# Epoch 1, Train Loss: 0.010520, Val Loss: 0.009128
# Epoch 2, Train Loss: 0.005894, Val Loss: 0.005809
# Epoch 3, Train Loss: 0.003765, Val Loss: 0.005442
# Epoch 4, Train Loss: 0.003432, Val Loss: 0.006021
# Epoch 5, Train Loss: 0.003279, Val Loss: 0.005640
# Epoch 6, Train Loss: 0.003196, Val Loss: 0.006263
# Epoch 7, Train Loss: 0.003078, Val Loss: 0.005849
# Epoch 8, Train Loss: 0.003044, Val Loss: 0.005849
# Epoch 9, Train Loss: 0.002980, Val Loss: 0.006243
# Epoch 10, Train Loss: 0.002902, Val Loss: 0.006178
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.010485769249498844
# Overall MAE: 0.09670943766832352
# Overall RMSE: 0.10240004516355862
# Processing: Target = scd41_co2 | Length = 12
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25213, 24, 18)
# Sequence target shape: (25213, 12)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38913, 24, 18)
# Sequence target shape: (38913, 12)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18113, 24, 18)
# Sequence target shape: (18113, 12)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 12])
# Epoch 1, Train Loss: 0.010491, Val Loss: 0.009926
# Epoch 2, Train Loss: 0.006069, Val Loss: 0.010841
# Epoch 3, Train Loss: 0.004270, Val Loss: 0.008568
# Epoch 4, Train Loss: 0.003957, Val Loss: 0.010224
# Epoch 5, Train Loss: 0.003822, Val Loss: 0.009846
# Epoch 6, Train Loss: 0.003742, Val Loss: 0.011411
# Epoch 7, Train Loss: 0.003667, Val Loss: 0.011908
# Epoch 8, Train Loss: 0.003611, Val Loss: 0.012323
# Epoch 9, Train Loss: 0.003543, Val Loss: 0.011771
# Epoch 10, Train Loss: 0.003503, Val Loss: 0.012434
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.016352634876966476
# Overall MAE: 0.118276447057724
# Overall RMSE: 0.12787742129463855
# Processing: Target = scd41_co2 | Length = 24
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25201, 24, 18)
# Sequence target shape: (25201, 24)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38901, 24, 18)
# Sequence target shape: (38901, 24)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18101, 24, 18)
# Sequence target shape: (18101, 24)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 24])
# Epoch 1, Train Loss: 0.010742, Val Loss: 0.009631
# Epoch 2, Train Loss: 0.006932, Val Loss: 0.013428
# Epoch 3, Train Loss: 0.005086, Val Loss: 0.007400
# Epoch 4, Train Loss: 0.004614, Val Loss: 0.007664
# Epoch 5, Train Loss: 0.004509, Val Loss: 0.007884
# Epoch 6, Train Loss: 0.004421, Val Loss: 0.006595
# Epoch 7, Train Loss: 0.004378, Val Loss: 0.007166
# Epoch 8, Train Loss: 0.004296, Val Loss: 0.006856
# Epoch 9, Train Loss: 0.004255, Val Loss: 0.007070
# Epoch 10, Train Loss: 0.004212, Val Loss: 0.006671
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.012412664480507374
# Overall MAE: 0.10038794577121735
# Overall RMSE: 0.11141213794065427
# Processing: Target = scd41_co2 | Length = 48
#
# Original data shape before sequencing: (25249, 18)
# Sequence input shape: (25177, 24, 18)
# Sequence target shape: (25177, 48)
#
# Original data shape before sequencing: (38949, 18)
# Sequence input shape: (38877, 24, 18)
# Sequence target shape: (38877, 48)
#
# Original data shape before sequencing: (18149, 18)
# Sequence input shape: (18077, 24, 18)
# Sequence target shape: (18077, 48)
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
#
# ========== DATALOADER ==========
# Batch input shape: torch.Size([32, 24, 18])
# Batch target shape: torch.Size([32, 48])
# Epoch 1, Train Loss: 0.012907, Val Loss: 0.010336
# Epoch 2, Train Loss: 0.007871, Val Loss: 0.013170
# Epoch 3, Train Loss: 0.006349, Val Loss: 0.013586
# Epoch 4, Train Loss: 0.005639, Val Loss: 0.013241
# Epoch 5, Train Loss: 0.005478, Val Loss: 0.013612
# Epoch 6, Train Loss: 0.005392, Val Loss: 0.012122
# Epoch 7, Train Loss: 0.005303, Val Loss: 0.012453
# Epoch 8, Train Loss: 0.005222, Val Loss: 0.013978
# Epoch 9, Train Loss: 0.005109, Val Loss: 0.013737
# Epoch 10, Train Loss: 0.005053, Val Loss: 0.012950
#
# ========== MODEL EVALUATION ==========
# Overall MSE: 0.0030296368058770895
# Overall MAE: 0.031120315194129944
# Overall RMSE: 0.05504213663982431
#
# ============================================================
# Rendering Visual Grid Directly Inside Jupyter Notebook Below:
# ============================================================
#  ALL EXPERIMENTS FINISHED! Everything displayed above.

# %% [markdown]
# ## 29. This Code Below Is Make Dir In Your Computer And Saved All Results Their

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

global TARGET, model_features

# ==========================================
# 1. PIPELINE FUNCTION WRAPPER
# ==========================================
def run_pipeline(target_feature, output_seq_length, epochs=10):
    global TARGET, model_features
    TARGET = target_feature 
    input_seq_length = 24  
    batch_size = 32
    
    X_train, y_train = create_sequences(train_scaled, model_features, input_seq_length, output_seq_length)
    X_val, y_val = create_sequences(val_scaled, model_features, input_seq_length, output_seq_length)
    X_test, y_test = create_sequences(test_scaled, model_features, input_seq_length, output_seq_length)
    
    train_loader = create_loader(X_train, y_train, batch_size, shuffle=True)
    val_loader = create_loader(X_val, y_val, batch_size, shuffle=False)
    test_loader = create_loader(X_test, y_test, batch_size, shuffle=False)
    
    model = CNNLSTMModel(input_size=X_train.shape[2], output_seq_length=output_seq_length)
    model, train_losses, val_losses = train_model(model, train_loader, val_loader, epochs=epochs)
    predictions, actuals, mse, mae, rmse = evaluate_model(model, test_loader)
    
    return {
        "predictions": predictions,
        "actuals": actuals,
        "mse": mse,
        "mae": mae,
        "rmse": rmse,
        "train_losses": train_losses,
        "val_losses": val_losses
    }

# ==========================================
# 2. MASTER EXPERIMENT LOOP (WITH CLEAN TWO-LINE PLOTS)
# ==========================================
output_lengths = [1, 6, 12]
target_features = [
    "ens160_aqi", 
    "ens160_tvoc", 
    "scd41_temperature", 
    "scd41_humidity", 
    "scd41_co2"
]

all_results_summary = []
output_base_dir = "model_experiment_results"
os.makedirs(output_base_dir, exist_ok=True)

print("Starting full automation run with fixed 2-line plotting logic...")

for target in target_features:
    for out_len in output_lengths:
        print("\n" + "="*50)
        print(f"RUNNING EXPERIMENT: Target = {target} | Output Length = {out_len}")
        print("="*50)
        
        try:
            results = run_pipeline(
                target_feature=target, 
                output_seq_length=out_len,
                epochs=10
            )
            
            all_results_summary.append({
                "Target_Feature": target,
                "Output_Length": out_len,
                "MSE": results["mse"],
                "MAE": results["mae"],
                "RMSE": results["rmse"]
            })
            
            # ------------------------------------------
            # FIXED GRAPH 1: Clean Actual vs Predicted (Exactly Two Lines)
            # ------------------------------------------
            plt.figure(figsize=(12, 6))
            
            # If multi-step (len 6 or 12), we plot the first step forecast across 200 time steps
            if out_len > 1:
                plot_actuals = results["actuals"][:200, 0]
                plot_preds = results["predictions"][:200, 0]
            else:
                plot_actuals = results["actuals"][:200].flatten()
                plot_preds = results["predictions"][:200].flatten()
                
            plt.plot(plot_actuals, label="Actual", color="blue", alpha=0.7)
            plt.plot(plot_preds, label="Predicted", color="orange", alpha=0.8)
            
            plt.title(f"Predictions vs Actuals - {target} (Len: {out_len})")
            plt.xlabel("Time Steps")
            plt.ylabel("Scaled Value")
            plt.legend()
            
            plot_filename = f"{output_base_dir}/plot_{target}_len_{out_len}.png"
            plt.savefig(plot_filename)
            plt.close()
            
            # ------------------------------------------
            # GRAPH 2: Training & Validation Loss Plot
            # ------------------------------------------
            plt.figure(figsize=(12, 6))
            plt.plot(results["train_losses"], label="Train Loss", color="blue")
            plt.plot(results["val_losses"], label="Validation Loss", color="orange")
            plt.title(f"Model Loss Over Epochs - {target} (Len: {out_len})")
            plt.xlabel("Epochs")
            plt.ylabel("Loss")
            plt.legend()
            
            loss_filename = f"{output_base_dir}/loss_{target}_len_{out_len}.png"
            plt.savefig(loss_filename)
            plt.close()
            
            print(f"Success! Clean 2-line graphs saved for {target} (len={out_len})")
            
        except Exception as e:
            print(f"Error during experiment [{target} | Length {out_len}]: {e}")

# ==========================================
# 3. EXPORT EXCEL/CSV SHEET
# ==========================================
if all_results_summary:
    df_summary = pd.DataFrame(all_results_summary)
    summary_path = f"{output_base_dir}/master_metrics_summary.csv"
    df_summary.to_csv(summary_path, index=False)
    print(f"\n DONE! All clean 15 variants computed. Folder: '{output_base_dir}'")
else:
    print("\n Loop execution failed.")
